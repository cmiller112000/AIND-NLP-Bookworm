# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (8aa6ded7-fc51-43a7-8efa-b6b4fcbb28fe)
# {
#   "environment_id": "8aa6ded7-fc51-43a7-8efa-b6b4fcbb28fe",
#   "name": "Bookworm",
#   "description": "A space to read and understand stories",
#   "created": "2017-06-21T00:50:12.190Z",
#   "updated": "2017-06-21T00:50:12.190Z",
#   "status": "active",
#   "read_only": false,
#   "size": 0,
#   "index_capacity": {
#     "disk_usage": {
#       "used_bytes": 24975313,
#       "total_bytes": 4294967296,
#       "used": "23.82 MB",
#       "total": "4 GB",
#       "percent_used": 0.58
#     },
#     "memory_usage": {
#       "used_bytes": 324914624,
#       "total_bytes": 1056309248,
#       "used": "309.86 MB",
#       "total": "1007.38 MB",
#       "percent_used": 30.76
#     }
#   }
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# View default configuration
cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "configuration_id": "00810bbe-4f8f-4b50-9ab9-ae61c74fa725",
#   "name": "Default Configuration",
#   "description": "The configuration used by default when creating a new collection without specifying a configuration_id.",
#   "created": "2017-06-21T00:50:12.264Z",
#   "updated": "2017-06-21T00:50:12.264Z",
#   "conversions": {
#     "word": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "min_size": 24,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 23,
#             "bold": true,
#             "italic": false
#           },
#           {
#             "level": 3,
#             "min_size": 14,
#             "max_size": 17,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 4,
#             "min_size": 13,
#             "max_size": 13,
#             "bold": true,
#             "italic": false
#           }
#         ],
#         "styles": [
#           {
#             "level": 1,
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ]
#           },
#           {
#             "level": 2,
#             "names": [
#               "subtitle"
#             ]
#           }
#         ]
#       }
#     },
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "min_size": 24,
#             "max_size": 80
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24,
#             "bold": true
#           },
#           {
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18,
#             "bold": true
#           },
#           {
#             "level": 4,
#             "min_size": 11,
#             "max_size": 13,
#             "bold": false,
#             "italic": false
#           }
#         ]
#       }
#     },
#     "html": {
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_content": {
#         "xpaths": []
#       },
#       "keep_content": {
#         "xpaths": []
#       },
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ]
#     },
#     "json_normalizations": []
#   },
#   "enrichments": [
#     {
#       "destination_field": "enriched_text",
#       "source_field": "text",
#       "enrichment": "alchemy_language",
#       "options": {
#         "extract": "keyword, entity, doc-sentiment, taxonomy, concept, relation",
#         "sentiment": true,
#         "quotations": true
#       }
#     }
#   ],
#   "normalizations": []
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**: Shakespeare History Plays
#
# All the Shakespeare History Plays as made available on the http://shakespeare.mit.edu/works.html website.  These series of plays covered the 'Wars of the Roses' period of time that depicts the series of reigns and the policial intrigue and conflict between the members of the Lancaster and York royal lines.  Supposedly, the "Game of Thrones" books are based on these wars.

# %%
# Test configuration on some sample text
data_dir = "shakespeare"
filename = os.path.join(data_dir, "john.html")
with open(filename, "r") as f:
    res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "status": "completed",
#   "enriched_field_units": 5,
#   "original_media_type": "text/html",
#   "snapshots": [
#     {
#       "step": "html_input",
#       "snapshot": {
#         "html": "<!DOCTYPE html PUBLIC \"-//W3C//DTD HTML 4.0 Transitional//EN\" \"http://www.w3.org/TR/REC-html40/loose.dtd\">\n<!-- saved from url=(0041)http://shakespeare.mit.edu/john/full.html -->\n<html><head><meta http-equiv=\"Content-Type\" content=\"text/html; charset=windows-1252\">\n <title>King John: Entire Play\n </title>\n \n <link rel=\"stylesheet\" type=\"text/css\" media=\"screen\" href=\"./john_files/shake.css\">\n </head>\n <body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n<table width=\"100%\" bgcolor=\"#CCF6F6\">\n<tbody><tr><td class=\"play\" align=\"center\">The Life and Death of King John\n</td></tr><tr><td class=\"nav\" align=\"center\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a  ...
#       }
#     },
#     {
#       "step": "html_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n <title>King John: Entire Play\n </title>\n \n <link href=\"./john_files/shake.css\" media=\"screen\" rel=\"stylesheet\" type=\"text/css\"/>\n \n </head>\n<body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n\n<table bgcolor=\"#CCF6F6\" width=\"100%\">\n<tbody><tr><td align=\"center\" class=\"play\">The Life and Death of King John\n</td></tr><tr><td align=\"center\" class=\"nav\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br/>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br/>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br/>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br/>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br/>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br/>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br/>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br/>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br/>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br/>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br/>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br/>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br/>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br/>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br/>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br/>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br/>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br/>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br/>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br/>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br/>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br/>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br/>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br/>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br/>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br/>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br/>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br/>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a name=\"speech11\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.31\">What now, my son! ...
#       }
#     },
#     {
#       "step": "json_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "King John: Entire Play\n "
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n <title>King John: Entire Play\n </title>\n \n <link href=\"./john_files/shake.css\" media=\"screen\" rel=\"stylesheet\" type=\"text/css\"/>\n \n \n</head>\n<body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n\n\n<table bgcolor=\"#CCF6F6\" width=\"100%\">\n<tbody><tr><td align=\"center\" class=\"play\">The Life and Death of King John\n</td></tr><tr><td align=\"center\" class=\"nav\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br/>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br/>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br/>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br/>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br/>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br/>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br/>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br/>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br/>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br/>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br/>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br/>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br/>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br/>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br/>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br/>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br/>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br/>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br/>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br/>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br/>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br/>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br/>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br/>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br/>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br/>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br/>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br/>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a name=\"speech11\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.31\">What no ...
#         "text": "King John: Entire Play\n\nThe Life and Death of King John\n\nShakespeare homepage | King John | Entire play\n\nACT I\n\nSCENE I. KING JOHN'S palace.\n\nEnter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON\n\nKING JOHN\n\nNow, say, Chatillon, what would France with us?\n\nCHATILLON\n\nThus, after greeting, speaks the King of France\nIn my behavior to the majesty,\nThe borrow'd majesty, of England here.\n\nQUEEN ELINOR\n\nA strange beginning: 'borrow'd majesty!'\n\nKING JOHN\n\nSilence, good mother; hear the embassy.\n\nCHATILLON\n\nPhilip of France, in right and true behalf\nOf thy deceased brother Geffrey's son,\nArthur Plantagenet, lays most lawful claim\nTo this fair island and the territories,\nTo Ireland, Poictiers, Anjou, Touraine, Maine,\nDesiring thee to lay aside the sword\nWhich sways usurpingly these several titles,\nAnd put these same into young Arthur's hand,\nThy nephew and right royal sovereign.\n\nKING JOHN\n\nWhat follows if we disallow of this?\n\nCHATILLON\n\nThe proud control of fierce and bloody war,\nTo enforce these rights so forcibly withheld.\n\nKING JOHN\n\nHere have we war for war and blood for blood,\nControlment for controlment: so answer France.\n\nCHATILLON\n\nThen take my king's defiance from my mouth,\nThe farthest limit of my embassy.\n\nKING JOHN\n\nBear mine to him, and so depart in peace:\nBe thou as lightning in the eyes of France;\nFor ere thou canst report I will be there,\nThe thunder of my cannon shall be heard:\nSo hence! Be thou the trumpet of our wrath\nAnd sullen presage of your own decay.\nAn honourable conduct let him have:\nPembroke, look to 't. Farewell, Chatillon.\n\nExeunt CHATILLON and PEMBROKE\n\nQUEEN ELINOR\n\nWhat now, my son! have I not ever said\nHow that ambitious Constance would not cease\nTill she had kindled France and all the world,\nUpon the right and party of her son?\nThis might have been prevented and made whole\nWith very easy arguments of love,\nWhich now the manage of two kingdoms must\nWith fearful bloody issue arbitrate.\n\nKING JOHN\n\nOur strong possession and our right for us.\n\nQUEEN ELINOR\n\nYour strong possession much more than your right,\nOr else it must go wrong with you and me:\nSo much my conscience whispers in your ear,\nWhich none but heaven and you and I shall hear.\n\nEnter a Sheriff\n\nESSEX\n\nMy liege, here is the strangest controversy\nCome from country to be judged by you,\nThat e'er I heard: shall I produce the men?\n\nKING JOHN\n\nLet them approach.\nOur abbeys and our priories shall pay\nThis expedition's charge.\n\nEnter ROBERT and the BASTARD\n\nWhat men are you?\n\nBASTARD\n\nYour faithful subject I, a gentleman\nBorn in Northamptonshire and eldest son,\nAs I suppose, to Robert Faulconbridge,\nA soldier, by the honour-giving hand\nOf Coeur-de-lion knighted in the field.\n\nKING JOHN\n\nWhat art thou?\n\nROBERT\n\nThe son and heir to that same Faulconbridge.\n\nKING JOHN\n\nIs that the elder, and art thou the heir?\nYou came not of one mother then, it seems.\n\nBASTARD\n\nMost certain of one mother, mighty king;\nThat is well known; and, as I think, one father:\nBut for the certain knowledge of that truth\nI put you o'er to heaven and to my mother:\nOf that I doubt, as all men's children may.\n\nQUEEN ELINOR\n\nOut on thee, rude man! thou dost shame thy mother\nAnd wound her honour with this diffidence.\n\nBASTARD\n\nI, madam? no, I have no reason for it;\nThat is my brother's plea and none of mine;\nThe which if he can prove, a' pops me out\nAt least from fair five hundred pound a year:\nHeaven guard my mother's honour and my land!\n\nKING JOHN\n\nA good blunt fellow. Why, being younger born,\nDoth he lay claim to thine inheritance?\n\nBASTARD\n\nI know not why, except to get the land.\nBut once he slander'd me with bastardy:\nBut whether I be as true begot or no,\nThat still I lay upon my mother's head,\nBut that I am as well begot, my liege,--\nFair fall the bones that took the ...
#         "metadata": {}
#       }
#     },
#     {
#       "step": "json_normalizations_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "King John: Entire Play\n "
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n <title>King John: Entire Play\n </title>\n \n <link href=\"./john_files/shake.css\" media=\"screen\" rel=\"stylesheet\" type=\"text/css\"/>\n \n \n</head>\n<body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n\n\n<table bgcolor=\"#CCF6F6\" width=\"100%\">\n<tbody><tr><td align=\"center\" class=\"play\">The Life and Death of King John\n</td></tr><tr><td align=\"center\" class=\"nav\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br/>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br/>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br/>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br/>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br/>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br/>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br/>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br/>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br/>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br/>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br/>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br/>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br/>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br/>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br/>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br/>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br/>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br/>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br/>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br/>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br/>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br/>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br/>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br/>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br/>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br/>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br/>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br/>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a name=\"speech11\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.31\">What no ...
#         "text": "King John: Entire Play\n\nThe Life and Death of King John\n\nShakespeare homepage | King John | Entire play\n\nACT I\n\nSCENE I. KING JOHN'S palace.\n\nEnter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON\n\nKING JOHN\n\nNow, say, Chatillon, what would France with us?\n\nCHATILLON\n\nThus, after greeting, speaks the King of France\nIn my behavior to the majesty,\nThe borrow'd majesty, of England here.\n\nQUEEN ELINOR\n\nA strange beginning: 'borrow'd majesty!'\n\nKING JOHN\n\nSilence, good mother; hear the embassy.\n\nCHATILLON\n\nPhilip of France, in right and true behalf\nOf thy deceased brother Geffrey's son,\nArthur Plantagenet, lays most lawful claim\nTo this fair island and the territories,\nTo Ireland, Poictiers, Anjou, Touraine, Maine,\nDesiring thee to lay aside the sword\nWhich sways usurpingly these several titles,\nAnd put these same into young Arthur's hand,\nThy nephew and right royal sovereign.\n\nKING JOHN\n\nWhat follows if we disallow of this?\n\nCHATILLON\n\nThe proud control of fierce and bloody war,\nTo enforce these rights so forcibly withheld.\n\nKING JOHN\n\nHere have we war for war and blood for blood,\nControlment for controlment: so answer France.\n\nCHATILLON\n\nThen take my king's defiance from my mouth,\nThe farthest limit of my embassy.\n\nKING JOHN\n\nBear mine to him, and so depart in peace:\nBe thou as lightning in the eyes of France;\nFor ere thou canst report I will be there,\nThe thunder of my cannon shall be heard:\nSo hence! Be thou the trumpet of our wrath\nAnd sullen presage of your own decay.\nAn honourable conduct let him have:\nPembroke, look to 't. Farewell, Chatillon.\n\nExeunt CHATILLON and PEMBROKE\n\nQUEEN ELINOR\n\nWhat now, my son! have I not ever said\nHow that ambitious Constance would not cease\nTill she had kindled France and all the world,\nUpon the right and party of her son?\nThis might have been prevented and made whole\nWith very easy arguments of love,\nWhich now the manage of two kingdoms must\nWith fearful bloody issue arbitrate.\n\nKING JOHN\n\nOur strong possession and our right for us.\n\nQUEEN ELINOR\n\nYour strong possession much more than your right,\nOr else it must go wrong with you and me:\nSo much my conscience whispers in your ear,\nWhich none but heaven and you and I shall hear.\n\nEnter a Sheriff\n\nESSEX\n\nMy liege, here is the strangest controversy\nCome from country to be judged by you,\nThat e'er I heard: shall I produce the men?\n\nKING JOHN\n\nLet them approach.\nOur abbeys and our priories shall pay\nThis expedition's charge.\n\nEnter ROBERT and the BASTARD\n\nWhat men are you?\n\nBASTARD\n\nYour faithful subject I, a gentleman\nBorn in Northamptonshire and eldest son,\nAs I suppose, to Robert Faulconbridge,\nA soldier, by the honour-giving hand\nOf Coeur-de-lion knighted in the field.\n\nKING JOHN\n\nWhat art thou?\n\nROBERT\n\nThe son and heir to that same Faulconbridge.\n\nKING JOHN\n\nIs that the elder, and art thou the heir?\nYou came not of one mother then, it seems.\n\nBASTARD\n\nMost certain of one mother, mighty king;\nThat is well known; and, as I think, one father:\nBut for the certain knowledge of that truth\nI put you o'er to heaven and to my mother:\nOf that I doubt, as all men's children may.\n\nQUEEN ELINOR\n\nOut on thee, rude man! thou dost shame thy mother\nAnd wound her honour with this diffidence.\n\nBASTARD\n\nI, madam? no, I have no reason for it;\nThat is my brother's plea and none of mine;\nThe which if he can prove, a' pops me out\nAt least from fair five hundred pound a year:\nHeaven guard my mother's honour and my land!\n\nKING JOHN\n\nA good blunt fellow. Why, being younger born,\nDoth he lay claim to thine inheritance?\n\nBASTARD\n\nI know not why, except to get the land.\nBut once he slander'd me with bastardy:\nBut whether I be as true begot or no,\nThat still I lay upon my mother's head,\nBut that I am as well begot, my liege,--\nFair fall the bones that took the ...
#         "metadata": {}
#       }
#     },
#     {
#       "step": "enrichments_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "King John: Entire Play\n "
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n <title>King John: Entire Play\n </title>\n \n <link href=\"./john_files/shake.css\" media=\"screen\" rel=\"stylesheet\" type=\"text/css\"/>\n \n \n</head>\n<body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n\n\n<table bgcolor=\"#CCF6F6\" width=\"100%\">\n<tbody><tr><td align=\"center\" class=\"play\">The Life and Death of King John\n</td></tr><tr><td align=\"center\" class=\"nav\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br/>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br/>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br/>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br/>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br/>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br/>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br/>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br/>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br/>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br/>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br/>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br/>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br/>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br/>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br/>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br/>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br/>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br/>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br/>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br/>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br/>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br/>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br/>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br/>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br/>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br/>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br/>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br/>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a name=\"speech11\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.31\">What no ...
#         "text": "King John: Entire Play\n\nThe Life and Death of King John\n\nShakespeare homepage | King John | Entire play\n\nACT I\n\nSCENE I. KING JOHN'S palace.\n\nEnter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON\n\nKING JOHN\n\nNow, say, Chatillon, what would France with us?\n\nCHATILLON\n\nThus, after greeting, speaks the King of France\nIn my behavior to the majesty,\nThe borrow'd majesty, of England here.\n\nQUEEN ELINOR\n\nA strange beginning: 'borrow'd majesty!'\n\nKING JOHN\n\nSilence, good mother; hear the embassy.\n\nCHATILLON\n\nPhilip of France, in right and true behalf\nOf thy deceased brother Geffrey's son,\nArthur Plantagenet, lays most lawful claim\nTo this fair island and the territories,\nTo Ireland, Poictiers, Anjou, Touraine, Maine,\nDesiring thee to lay aside the sword\nWhich sways usurpingly these several titles,\nAnd put these same into young Arthur's hand,\nThy nephew and right royal sovereign.\n\nKING JOHN\n\nWhat follows if we disallow of this?\n\nCHATILLON\n\nThe proud control of fierce and bloody war,\nTo enforce these rights so forcibly withheld.\n\nKING JOHN\n\nHere have we war for war and blood for blood,\nControlment for controlment: so answer France.\n\nCHATILLON\n\nThen take my king's defiance from my mouth,\nThe farthest limit of my embassy.\n\nKING JOHN\n\nBear mine to him, and so depart in peace:\nBe thou as lightning in the eyes of France;\nFor ere thou canst report I will be there,\nThe thunder of my cannon shall be heard:\nSo hence! Be thou the trumpet of our wrath\nAnd sullen presage of your own decay.\nAn honourable conduct let him have:\nPembroke, look to 't. Farewell, Chatillon.\n\nExeunt CHATILLON and PEMBROKE\n\nQUEEN ELINOR\n\nWhat now, my son! have I not ever said\nHow that ambitious Constance would not cease\nTill she had kindled France and all the world,\nUpon the right and party of her son?\nThis might have been prevented and made whole\nWith very easy arguments of love,\nWhich now the manage of two kingdoms must\nWith fearful bloody issue arbitrate.\n\nKING JOHN\n\nOur strong possession and our right for us.\n\nQUEEN ELINOR\n\nYour strong possession much more than your right,\nOr else it must go wrong with you and me:\nSo much my conscience whispers in your ear,\nWhich none but heaven and you and I shall hear.\n\nEnter a Sheriff\n\nESSEX\n\nMy liege, here is the strangest controversy\nCome from country to be judged by you,\nThat e'er I heard: shall I produce the men?\n\nKING JOHN\n\nLet them approach.\nOur abbeys and our priories shall pay\nThis expedition's charge.\n\nEnter ROBERT and the BASTARD\n\nWhat men are you?\n\nBASTARD\n\nYour faithful subject I, a gentleman\nBorn in Northamptonshire and eldest son,\nAs I suppose, to Robert Faulconbridge,\nA soldier, by the honour-giving hand\nOf Coeur-de-lion knighted in the field.\n\nKING JOHN\n\nWhat art thou?\n\nROBERT\n\nThe son and heir to that same Faulconbridge.\n\nKING JOHN\n\nIs that the elder, and art thou the heir?\nYou came not of one mother then, it seems.\n\nBASTARD\n\nMost certain of one mother, mighty king;\nThat is well known; and, as I think, one father:\nBut for the certain knowledge of that truth\nI put you o'er to heaven and to my mother:\nOf that I doubt, as all men's children may.\n\nQUEEN ELINOR\n\nOut on thee, rude man! thou dost shame thy mother\nAnd wound her honour with this diffidence.\n\nBASTARD\n\nI, madam? no, I have no reason for it;\nThat is my brother's plea and none of mine;\nThe which if he can prove, a' pops me out\nAt least from fair five hundred pound a year:\nHeaven guard my mother's honour and my land!\n\nKING JOHN\n\nA good blunt fellow. Why, being younger born,\nDoth he lay claim to thine inheritance?\n\nBASTARD\n\nI know not why, except to get the land.\nBut once he slander'd me with bastardy:\nBut whether I be as true begot or no,\nThat still I lay upon my mother's head,\nBut that I am as well begot, my liege,--\nFair fall the bones that took the ...
#         "metadata": {},
#         "enriched_text": {
#           "status": "OK",
#           "warningMessage": "truncated-oversized-text-content",
#           "language": "english",
#           "docSentiment": {
#             "type": "negative",
#             "score": -0.109708,
#             "mixed": true
#           },
#           "concepts": [
#             {
#               "text": "Philip II of France",
#               "relevance": 0.966415,
#               "dbpedia": "http://dbpedia.org/resource/Philip_II_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.068m5",
#               "yago": "http://yago-knowledge.org/resource/Philip_II_of_France"
#             },
#             {
#               "text": "John of England",
#               "relevance": 0.914807,
#               "dbpedia": "http://dbpedia.org/resource/John_of_England",
#               "yago": "http://yago-knowledge.org/resource/John_of_England"
#             },
#             {
#               "text": "Philip II of Spain",
#               "relevance": 0.793564,
#               "dbpedia": "http://dbpedia.org/resource/Philip_II_of_Spain",
#               "freebase": "http://rdf.freebase.com/ns/m.0f6fz",
#               "yago": "http://yago-knowledge.org/resource/Philip_II_of_Spain"
#             },
#             {
#               "text": "House of Capet",
#               "relevance": 0.756708,
#               "dbpedia": "http://dbpedia.org/resource/House_of_Capet",
#               "freebase": "http://rdf.freebase.com/ns/m.05mxmt",
#               "yago": "http://yago-knowledge.org/resource/House_of_Capet"
#             },
#             {
#               "text": "Louis VIII of France",
#               "relevance": 0.717723,
#               "dbpedia": "http://dbpedia.org/resource/Louis_VIII_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kp62",
#               "yago": "http://yago-knowledge.org/resource/Louis_VIII_of_France"
#             },
#             {
#               "text": "Philip IV of France",
#               "relevance": 0.687205,
#               "dbpedia": "http://dbpedia.org/resource/Philip_IV_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0k7mm",
#               "yago": "http://yago-knowledge.org/resource/Philip_IV_of_France"
#             },
#             {
#               "text": "Thou",
#               "relevance": 0.66748,
#               "dbpedia": "http://dbpedia.org/resource/Thou",
#               "freebase": "http://rdf.freebase.com/ns/m.01j4wt",
#               "yago": "http://yago-knowledge.org/resource/Thou"
#             },
#             {
#               "text": "Philip I of France",
#               "relevance": 0.655121,
#               "dbpedia": "http://dbpedia.org/resource/Philip_I_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kg_6",
#               "yago": "http://yago-knowledge.org/resource/Philip_I_of_France"
#             },
#             {
#               "text": "Louis VI of France",
#               "relevance": 0.618934,
#               "dbpedia": "http://dbpedia.org/resource/Louis_VI_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kg1d",
#               "yago": "http://yago-knowledge.org/resource/Louis_VI_of_France"
#             },
#             {
#               "text": "French monarchs",
#               "relevance": 0.610358,
#               "dbpedia": "http://dbpedia.org/resource/French_monarchs"
#             },
#             {
#               "text": "Philip V of France",
#               "relevance": 0.584052,
#               "dbpedia": "http://dbpedia.org/resource/Philip_V_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0khfr",
#               "yago": "http://yago-knowledge.org/resource/Philip_V_of_France"
#             },
#             {
#               "text": "Arthur I, Duke of Brittany",
#               "relevance": 0.576688,
#               "dbpedia": "http://dbpedia.org/resource/Arthur_I,_Duke_of_Brittany",
#               "freebase": "http://rdf.freebase.com/ns/m.018tz_",
#               "yago": "http://yago-knowledge.org/resource/Arthur_I,_Duke_of_Brittany"
#             },
#             {
#               "text": "Philip III of France",
#               "relevance": 0.558061,
#               "dbpedia": "http://dbpedia.org/resource/Philip_III_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kg_q",
#               "yago": "http://yago-knowledge.org/resource/Philip_III_of_France"
#             },
#             {
#               "text": "Henry VI of England",
#               "relevance": 0.528776,
#               "dbpedia": "http://dbpedia.org/resource/Henry_VI_of_England",
#               "freebase": "http://rdf.freebase.com/ns/m.0cmz2",
#               "yago": "http://yago-knowledge.org/resource/Henry_VI_of_England"
#             },
#             {
#               "text": "Louis VII of France",
#               "relevance": 0.528617,
#               "dbpedia": "http://dbpedia.org/resource/Louis_VII_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0czd0",
#               "yago": "http://yago-knowledge.org/resource/Louis_VII_of_France"
#             },
#             {
#               "text": "Richard I of England",
#               "relevance": 0.513018,
#               "dbpedia": "http://dbpedia.org/resource/Richard_I_of_England",
#               "freebase": "http://rdf.freebase.com/ns/m.06kq_",
#               "yago": "http://yago-knowledge.org/resource/Richard_I_of_England"
#             },
#             {
#               "text": "Kingdom of England",
#               "relevance": 0.474988,
#               "dbpedia": "http://dbpedia.org/resource/Kingdom_of_England",
#               "freebase": "http://rdf.freebase.com/ns/m.024pcx",
#               "yago": "http://yago-knowledge.org/resource/Kingdom_of_England"
#             },
#             {
#               "text": "Henry I of France",
#               "relevance": 0.469108,
#               "dbpedia": "http://dbpedia.org/resource/Henry_I_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kfxk",
#               "yago": "http://yago-knowledge.org/resource/Henry_I_of_France"
#             },
#             {
#               "text": "Philip VI of France",
#               "relevance": 0.460219,
#               "dbpedia": "http://dbpedia.org/resource/Philip_VI_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0k9ld",
#               "yago": "http://yago-knowledge.org/resource/Philip_VI_of_France"
#             },
#             {
#               "text": "The Life and Death of King John",
#               "relevance": 0.444751,
#               "dbpedia": "http://dbpedia.org/resource/The_Life_and_Death_of_King_John",
#               "freebase": "http://rdf.freebase.com/ns/m.0hnj0"
#             },
#             {
#               "text": "Louis X of France",
#               "relevance": 0.432978,
#               "dbpedia": "http://dbpedia.org/resource/Louis_X_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0kg99",
#               "yago": "http://yago-knowledge.org/resource/Louis_X_of_France"
#             },
#             {
#               "text": "King Philip's War",
#               "relevance": 0.424037,
#               "dbpedia": "http://dbpedia.org/resource/King_Philip's_War",
#               "freebase": "http://rdf.freebase.com/ns/m.01tg0c",
#               "yago": "http://yago-knowledge.org/resource/King_Philip's_War"
#             },
#             {
#               "text": "Louis XIII of France",
#               "relevance": 0.423236,
#               "dbpedia": "http://dbpedia.org/resource/Louis_XIII_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0k6xj",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwR9aFJwpEbGdrcN5Y29ycA",
#               "yago": "http://yago-knowledge.org/resource/Louis_XIII_of_France"
#             },
#             {
#               "text": "Louis IX of France",
#               "relevance": 0.41688,
#               "dbpedia": "http://dbpedia.org/resource/Louis_IX_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.04pv3",
#               "yago": "http://yago-knowledge.org/resource/Louis_IX_of_France"
#             },
#             {
#               "text": "Early Modern English",
#               "relevance": 0.414929,
#               "dbpedia": "http://dbpedia.org/resource/Early_Modern_English",
#               "freebase": "http://rdf.freebase.com/ns/m.03yb_1",
#               "yago": "http://yago-knowledge.org/resource/Early_Modern_English"
#             },
#             {
#               "text": "Louis XVI of France",
#               "relevance": 0.401512,
#               "dbpedia": "http://dbpedia.org/resource/Louis_XVI_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0dj9w",
#               "opencyc": "http://sw.opencyc.org/concept/Mx4rwUnqopwpEbGdrcN5Y29ycA",
#               "yago": "http://yago-knowledge.org/resource/Louis_XVI_of_France"
#             },
#             {
#               "text": "Charles IV of France",
#               "relevance": 0.397813,
#               "dbpedia": "http://dbpedia.org/resource/Charles_IV_of_France",
#               "freebase": "http://rdf.freebase.com/ns/m.0khf8",
#               "yago": "http://yago-knowledge.org/resource/Charles_IV_of_France"
#             },
#             {
#               "text": "Mother",
#               "relevance": 0.397256,
#               "dbpedia": "http://dbpedia.org/resource/Mother",
#               "freebase": "http://rdf.freebase.com/ns/m.0lbxz"
#             },
#             {
#               "text": "Benjamin Church",
#               "relevance": 0.393678,
#               "dbpedia": "http://dbpedia.org/resource/Benjamin_Church_(military_officer)",
#               "freebase": "http://rdf.freebase.com/ns/m.05pkrg",
#               "yago": "http://yago-knowledge.org/resource/Benjamin_Church_(military_officer)"
#             },
#             {
#               "text": "Mary I of England",
#               "relevance": 0.39361,
#               "dbpedia": "http://dbpedia.org/resource/Mary_I_of_England",
#               "freebase": "http://rdf.freebase.com/ns/m.056j9",
#               "yago": "http://yago-knowledge.org/resource/Mary_I_of_England"
#             }
#           ],
#           "entities": [
#             {
#               "type": "Person",
#               "relevance": 0.841569,
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.887908,
#                 "mixed": false
#               },
#               "count": 42,
#               "text": "KING PHILIP"
#             },
#             {
#               "type": "Country",
#               "relevance": 0.669626,
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.0848756,
#                 "mixed": true
#               },
#               "count": 43,
#               "text": "France",
#               "disambiguated": {
#                 "name": "July Monarchy",
#                 "dbpedia": "http://dbpedia.org/resource/July_Monarchy",
#                 "freebase": "http://rdf.freebase.com/ns/m.020v1q",
#                 "yago": "http://yago-knowledge.org/resource/July_Monarchy"
#               }
#             },
#             {
#               "type": "Country",
#               "relevance": 0.551717,
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.345574,
#                 "mixed": true
#               },
#               "count": 28,
#               "text": "England"
#             },
#             {
#               "type": "Person",
#               "relevance": 0.480765,
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.419729,
#                 "mixed": false
#               },
#               "count": 20,
#               "text": "QUEEN ELINOR"
#             },
#             {
#               "type": "Country",
#               "relevance": 0.453363,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "count": 19,
#               "text": "AUSTRIA"
#             },
#             {
#               "type": "Person",
#               "relevance": 0.452309,
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.704448,
#                 "mixed": false
#               },
#               "count": 14,
#               "text": "uncle John"
#             },
#             {
#               "type": "Person",
#               "relevance": 0.391631,
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.460206,
#                 "mixed": false
#               },
#               "count": 13,
#               "text": "Arthur"
#             },
#             {
#               "type": "Person",
#               "relevance": 0.373106,
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.122107,
#                 "mixed": true
#               },
#               "count": 22,
#               "text": "Sir Robert",
#               "disambiguated": {
#                 "name": "Bob Kerslake",
#                 "dbpedia": "http://dbpedia.org/resource/Bob_Kerslake",
#                 "freebase": "http://rdf.freebase.com/ns/m.0289vc5",
#                 "yago": "http://yago-knowledge.org/resource/Bob_Kerslake"
#               }
#             },
#             {
#               "type": "Organization",
#               "relevance": 0.344543,
#               "sentiment": {
#                 "type": "positive",
#                 "score": 0.6235,
#                 "mixed": false
#               },
#               "count": 8,
#               "text": "Lords",
#               "disambiguated": {
#                 "name": "Lords Feoffees",
#                 "dbpedia": "http://dbpedia.org/resource/Lords_Feoffees",
#                 "freebase": "http://rdf.freebase.com/ns/m.09bgyt",
#                 "yago": "http://yago-knowledge.org/resource/Lords_Feoffees"
#               }
#             },
#             {
#               "type": "Person",
#               "relevance": 0.33709,
#               "sentiment": {
#                 "type": "negative",
#                 "score": -0.604047,
#                 "mixed": false
#               },
#               "count": 7,
#               "text": "O Lewis"
#             },
#             {
#               "type": "City",
#               "relevance": 0.328747,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "count": 8,
#               "text": "Angiers",
#               "disambiguated": {
#                 "subType": [],
#                 "name": "Angers",
#                 "website": "http://www.angers.fr/",
#                 "dbpedia": "http://dbpedia.org/resource/Angers",
#                 "freebase": "http://rdf.freebase.com/ns/m.0l4lj",
#                 "geonames": "http://sws.geonames.org/3037656/"
#               }
#             },
#             {
#               "type": "Person",
#               "relevance": 0.321398,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "count": 7,
#               "text": "Lady Blanch"
#             },
#             {
#               "type": "Company",
#               "relevance": 0.318943,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "count": 8,
#               "text": "BLANCH"
#             },
#             {
#               "type": "Person",
# ...
#               }
#             },
#             {
#               "sentence": " That is well known; and, as I think, one father:",
#               "subject": {
#                 "text": "That"
#               },
#               "action": {
#                 "text": "is",
#                 "lemmatized": "be",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 }
#               },
#               "object": {
#                 "text": "well known",
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.461361,
#                   "mixed": false
#                 }
#               }
#             },
#             {
#               "sentence": " Out on thee, rude man! thou dost shame thy mother",
#               "subject": {
#                 "text": "shame",
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.769909,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "shame"
#                   }
#                 ]
#               },
#               "action": {
#                 "text": "dost",
#                 "lemmatized": "dost",
#                 "verb": {
#                   "text": "dost",
#                   "tense": "past"
#                 }
#               },
#               "object": {
#                 "text": "thy mother",
#                 "sentiment": {
#                   "type": "positive",
#                   "score": 0.560203,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "thy mother"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " And wound her honour with this diffidence.",
#               "subject": {
#                 "text": "her honour",
#                 "keywords": [
#                   {
#                     "text": "honour"
#                   }
#                 ]
#               },
#               "action": {
#                 "text": "wound",
#                 "lemmatized": "wind",
#                 "verb": {
#                   "text": "wind",
#                   "tense": "past"
#                 }
#               },
#               "object": {
#                 "text": "with this diffidence",
#                 "keywords": [
#                   {
#                     "text": "diffidence"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " I, madam? no, I have no reason for it;",
#               "subject": {
#                 "text": "I"
#               },
#               "action": {
#                 "text": "have",
#                 "lemmatized": "have",
#                 "verb": {
#                   "text": "have",
#                   "tense": "present"
#                 }
#               },
#               "object": {
#                 "text": "no reason for it",
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.754472,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "reason"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " That is my brother's plea and none of mine;",
#               "subject": {
#                 "text": "That"
#               },
#               "action": {
#                 "text": "is",
#                 "lemmatized": "be",
#                 "verb": {
#                   "text": "be",
#                   "tense": "present"
#                 }
#               },
#               "object": {
#                 "text": "my brother's plea and none of mine",
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.915734,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "plea"
#                   },
#                   {
#                     "text": "brother"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " Doth he lay claim to thine inheritance?",
#               "subject": {
#                 "text": "he"
#               },
#               "action": {
#                 "text": "lay",
#                 "lemmatized": "lie",
#                 "verb": {
#                   "text": "lie",
#                   "tense": "past"
#                 }
#               },
#               "object": {
#                 "text": "claim to thine inheritance",
#                 "keywords": [
#                   {
#                     "text": "claim"
#                   },
#                   {
#                     "text": "inheritance"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " Doth he lay claim to thine inheritance?",
#               "subject": {
#                 "text": "he"
#               },
#               "action": {
#                 "text": "to thine",
#                 "lemmatized": "to thine",
#                 "verb": {
#                   "text": "thine",
#                   "tense": "future"
#                 }
#               },
#               "object": {
#                 "text": "inheritance",
#                 "keywords": [
#                   {
#                     "text": "inheritance"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " I know not why, except to get the land.",
#               "subject": {
#                 "text": "I"
#               },
#               "action": {
#                 "text": "know",
#                 "lemmatized": "know",
#                 "verb": {
#                   "text": "know",
#                   "tense": "present"
#                 }
#               },
#               "object": {
#                 "text": "not why, except to get the land",
#                 "sentiment": {
#                   "type": "negative",
#                   "score": -0.439279,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "land"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " I know not why, except to get the land.",
#               "subject": {
#                 "text": "I"
#               },
#               "action": {
#                 "text": "to get",
#                 "lemmatized": "to get",
#                 "verb": {
#                   "text": "get",
#                   "tense": "future"
#                 }
#               },
#               "object": {
#                 "text": "the land",
#                 "keywords": [
#                   {
#                     "text": "land"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " But once he slander'd me with bastardy:",
#               "subject": {
#                 "text": "he"
#               },
#               "action": {
#                 "text": "slander",
#                 "lemmatized": "slander",
#                 "verb": {
#                   "text": "slander",
#                   "tense": "present"
#                 }
#               },
#               "object": {
#                 "text": "with bastardy",
#                 "sentimentFromSubject": {
#                   "type": "negative",
#                   "score": -0.77074,
#                   "mixed": false
#                 },
#                 "keywords": [
#                   {
#                     "text": "bastardy"
#                   }
#                 ]
#               }
#             },
#             {
#               "sentence": " That still I lay upon my mother's head,",
#               "subject": {
#                 "text": "I"
#               },
#               "action": {
#                 "text": "lay",
#                 "lemmatized": "lie",
#                 "verb": {
#                   "text": "lie",
#                   "tense": "past"
#                 }
#               }
#             }
#           ],
#           "taxonomy": [
#             {
#               "label": "/travel/tourist destinations/france",
#               "score": 0.589227,
#               "confident": false
#             },
#             {
#               "label": "/science/social science/history/medieval history",
#               "score": 0.500512,
#               "confident": false
#             },
#             {
#               "label": "/family and parenting/children",
#               "score": 0.49403,
#               "confident": false
#             }
#           ],
#           "keywords": [
#             {
#               "relevance": 0.982432,
#               "sentiment": {
#                 "score": 0.555817,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "king john"
#             },
#             {
#               "relevance": 0.817777,
#               "sentiment": {
#                 "score": 0.412744,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "QUEEN ELINOR"
#             },
#             {
#               "relevance": 0.690969,
#               "sentiment": {
#                 "score": -0.65183,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "bastard"
#             },
#             {
#               "relevance": 0.654041,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.166815,
#                 "type": "positive"
#               },
#               "text": "sir robert"
#             },
#             {
#               "relevance": 0.639647,
#               "sentiment": {
#                 "mixed": true,
#                 "score": -0.064096,
#                 "type": "negative"
#               },
#               "text": "France"
#             },
#             {
#               "relevance": 0.638287,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.250339,
#                 "type": "positive"
#               },
#               "text": "philip"
#             },
#             {
#               "relevance": 0.636941,
#               "sentiment": {
#                 "score": 0.371875,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "thou thy desire"
#             },
#             {
#               "relevance": 0.618492,
#               "sentiment": {
#                 "score": 0.557092,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "old sir Robert"
#             },
#             {
#               "relevance": 0.617086,
#               "sentiment": {
#                 "score": 0.452636,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "hast thou"
#             },
#             {
#               "relevance": 0.612143,
#               "sentiment": {
#                 "score": -0.600452,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "thou art"
#             },
#             {
#               "relevance": 0.59981,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "thou unreverend boy"
#             },
#             {
#               "relevance": 0.599412,
#               "sentiment": {
#                 "mixed": true,
#                 "score": -0.0998358,
#                 "type": "negative"
#               },
#               "text": "son"
#             },
#             {
#               "relevance": 0.599351,
#               "sentiment": {
#                 "score": -0.420019,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "art thou"
#             },
#             {
#               "relevance": 0.598999,
#               "sentiment": {
#                 "score": 0.457454,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "constance"
#             },
#             {
#               "relevance": 0.593668,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.0511407,
#                 "type": "positive"
#               },
#               "text": "England"
#             },
#             {
#               "relevance": 0.592631,
#               "sentiment": {
#                 "mixed": true,
#                 "score": -0.401102,
#                 "type": "negative"
#               },
#               "text": "thy brother"
#             },
#             {
#               "relevance": 0.590425,
#               "sentiment": {
#                 "score": 0.570155,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "right thou"
#             },
#             {
#               "relevance": 0.589835,
#               "sentiment": {
#                 "score": -0.681349,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "Thou unadvised scold"
#             },
#             {
#               "relevance": 0.588918,
#               "sentiment": {
#                 "score": -0.744992,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "Thou monstrous slanderer"
#             },
#             {
#               "relevance": 0.588855,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Thou monstrous injurer"
#             },
#             {
#               "relevance": 0.588082,
#               "sentiment": {
#                 "score": -0.538782,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "thou hast misspoke"
#             },
#             {
#               "relevance": 0.587433,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.0686216,
#                 "type": "positive"
#               },
#               "text": "thy son"
#             },
#             {
#               "relevance": 0.587341,
#               "sentiment": {
#                 "score": -0.656377,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "thy bastard"
#             },
#             {
#               "relevance": 0.585724,
#               "sentiment": {
#                 "score": 0.433941,
#                 "type": "positive",
#                 "mixed": false
#               },
#               "text": "I. KING JOHN"
#             },
#             {
#               "relevance": 0.583967,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.297967,
#                 "type": "positive"
#               },
#               "text": "father"
#             },
#             {
#               "relevance": 0.583175,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.0111449,
#                 "type": "positive"
#               },
#               "text": "mother"
#             },
#             {
#               "relevance": 0.582554,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "thou dost"
#             },
#             {
#               "relevance": 0.582327,
#               "sentiment": {
#                 "mixed": true,
#                 "score": 0.121962,
#                 "type": "positive"
#               },
#               "text": "hath"
#             },
#             {
#               "relevance": 0.581653,
#               "sentiment": {
#                 "score": -0.420019,
#                 "type": "negative",
#                 "mixed": false
#               },
#               "text": "fool art thou"
#             },
#             {
#               "relevance": 0.579756,
#               "sentiment": {
#                 "type": "neutral",
#                 "mixed": false
#               },
#               "text": "Thou cold-blooded slave"
#             }
#           ]
#         }
#       }
#     }
#   ],
#   "notices": []
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "extracted_metadata": {
#     "title": "King John: Entire Play\n "
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n <title>King John: Entire Play\n </title>\n \n <link href=\"./john_files/shake.css\" media=\"screen\" rel=\"stylesheet\" type=\"text/css\"/>\n \n \n</head>\n<body bgcolor=\"#ffffff\" text=\"#000000\" waid71fa0d88-5390-4b5b-a2f4-e45fa93d85e2=\"SA password protect entry checker\">\n\n\n\n<table bgcolor=\"#CCF6F6\" width=\"100%\">\n<tbody><tr><td align=\"center\" class=\"play\">The Life and Death of King John\n</td></tr><tr><td align=\"center\" class=\"nav\">\n      <a href=\"http://shakespeare.mit.edu/Shakespeare\">Shakespeare homepage</a> \n    | <a href=\"http://shakespeare.mit.edu/john/\">King John</a> \n    | Entire play\n</td></tr></tbody></table>\n\n<h3>ACT I</h3>\n<h3>SCENE I. KING JOHN'S palace.</h3>\n<p></p><blockquote>\n<i>Enter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON</i>\n</blockquote>\n\n<a name=\"speech1\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.1\">Now, say, Chatillon, what would France with us?</a><br/>\n</blockquote>\n\n<a name=\"speech2\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.2\">Thus, after greeting, speaks the King of France</a><br/>\n<a name=\"1.1.3\">In my behavior to the majesty,</a><br/>\n<a name=\"1.1.4\">The borrow'd majesty, of England here.</a><br/>\n</blockquote>\n\n<a name=\"speech3\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.5\">A strange beginning: 'borrow'd majesty!'</a><br/>\n</blockquote>\n\n<a name=\"speech4\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.6\">Silence, good mother; hear the embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech5\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.7\">Philip of France, in right and true behalf</a><br/>\n<a name=\"1.1.8\">Of thy deceased brother Geffrey's son,</a><br/>\n<a name=\"1.1.9\">Arthur Plantagenet, lays most lawful claim</a><br/>\n<a name=\"1.1.10\">To this fair island and the territories,</a><br/>\n<a name=\"1.1.11\">To Ireland, Poictiers, Anjou, Touraine, Maine,</a><br/>\n<a name=\"1.1.12\">Desiring thee to lay aside the sword</a><br/>\n<a name=\"1.1.13\">Which sways usurpingly these several titles,</a><br/>\n<a name=\"1.1.14\">And put these same into young Arthur's hand,</a><br/>\n<a name=\"1.1.15\">Thy nephew and right royal sovereign.</a><br/>\n</blockquote>\n\n<a name=\"speech6\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.16\">What follows if we disallow of this?</a><br/>\n</blockquote>\n\n<a name=\"speech7\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.17\">The proud control of fierce and bloody war,</a><br/>\n<a name=\"1.1.18\">To enforce these rights so forcibly withheld.</a><br/>\n</blockquote>\n\n<a name=\"speech8\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.19\">Here have we war for war and blood for blood,</a><br/>\n<a name=\"1.1.20\">Controlment for controlment: so answer France.</a><br/>\n</blockquote>\n\n<a name=\"speech9\"><b>CHATILLON</b></a>\n<blockquote>\n<a name=\"1.1.21\">Then take my king's defiance from my mouth,</a><br/>\n<a name=\"1.1.22\">The farthest limit of my embassy.</a><br/>\n</blockquote>\n\n<a name=\"speech10\"><b>KING JOHN</b></a>\n<blockquote>\n<a name=\"1.1.23\">Bear mine to him, and so depart in peace:</a><br/>\n<a name=\"1.1.24\">Be thou as lightning in the eyes of France;</a><br/>\n<a name=\"1.1.25\">For ere thou canst report I will be there,</a><br/>\n<a name=\"1.1.26\">The thunder of my cannon shall be heard:</a><br/>\n<a name=\"1.1.27\">So hence! Be thou the trumpet of our wrath</a><br/>\n<a name=\"1.1.28\">And sullen presage of your own decay.</a><br/>\n<a name=\"1.1.29\">An honourable conduct let him have:</a><br/>\n<a name=\"1.1.30\">Pembroke, look to 't. Farewell, Chatillon.</a><br/>\n<p><i>Exeunt CHATILLON and PEMBROKE</i></p>\n</blockquote>\n\n<a name=\"speech11\"><b>QUEEN ELINOR</b></a>\n<blockquote>\n<a name=\"1.1.31\">What now, my  ...
#   "text": "King John: Entire Play\n\nThe Life and Death of King John\n\nShakespeare homepage | King John | Entire play\n\nACT I\n\nSCENE I. KING JOHN'S palace.\n\nEnter KING JOHN, QUEEN ELINOR, PEMBROKE, ESSEX, SALISBURY, and others, with CHATILLON\n\nKING JOHN\n\nNow, say, Chatillon, what would France with us?\n\nCHATILLON\n\nThus, after greeting, speaks the King of France\nIn my behavior to the majesty,\nThe borrow'd majesty, of England here.\n\nQUEEN ELINOR\n\nA strange beginning: 'borrow'd majesty!'\n\nKING JOHN\n\nSilence, good mother; hear the embassy.\n\nCHATILLON\n\nPhilip of France, in right and true behalf\nOf thy deceased brother Geffrey's son,\nArthur Plantagenet, lays most lawful claim\nTo this fair island and the territories,\nTo Ireland, Poictiers, Anjou, Touraine, Maine,\nDesiring thee to lay aside the sword\nWhich sways usurpingly these several titles,\nAnd put these same into young Arthur's hand,\nThy nephew and right royal sovereign.\n\nKING JOHN\n\nWhat follows if we disallow of this?\n\nCHATILLON\n\nThe proud control of fierce and bloody war,\nTo enforce these rights so forcibly withheld.\n\nKING JOHN\n\nHere have we war for war and blood for blood,\nControlment for controlment: so answer France.\n\nCHATILLON\n\nThen take my king's defiance from my mouth,\nThe farthest limit of my embassy.\n\nKING JOHN\n\nBear mine to him, and so depart in peace:\nBe thou as lightning in the eyes of France;\nFor ere thou canst report I will be there,\nThe thunder of my cannon shall be heard:\nSo hence! Be thou the trumpet of our wrath\nAnd sullen presage of your own decay.\nAn honourable conduct let him have:\nPembroke, look to 't. Farewell, Chatillon.\n\nExeunt CHATILLON and PEMBROKE\n\nQUEEN ELINOR\n\nWhat now, my son! have I not ever said\nHow that ambitious Constance would not cease\nTill she had kindled France and all the world,\nUpon the right and party of her son?\nThis might have been prevented and made whole\nWith very easy arguments of love,\nWhich now the manage of two kingdoms must\nWith fearful bloody issue arbitrate.\n\nKING JOHN\n\nOur strong possession and our right for us.\n\nQUEEN ELINOR\n\nYour strong possession much more than your right,\nOr else it must go wrong with you and me:\nSo much my conscience whispers in your ear,\nWhich none but heaven and you and I shall hear.\n\nEnter a Sheriff\n\nESSEX\n\nMy liege, here is the strangest controversy\nCome from country to be judged by you,\nThat e'er I heard: shall I produce the men?\n\nKING JOHN\n\nLet them approach.\nOur abbeys and our priories shall pay\nThis expedition's charge.\n\nEnter ROBERT and the BASTARD\n\nWhat men are you?\n\nBASTARD\n\nYour faithful subject I, a gentleman\nBorn in Northamptonshire and eldest son,\nAs I suppose, to Robert Faulconbridge,\nA soldier, by the honour-giving hand\nOf Coeur-de-lion knighted in the field.\n\nKING JOHN\n\nWhat art thou?\n\nROBERT\n\nThe son and heir to that same Faulconbridge.\n\nKING JOHN\n\nIs that the elder, and art thou the heir?\nYou came not of one mother then, it seems.\n\nBASTARD\n\nMost certain of one mother, mighty king;\nThat is well known; and, as I think, one father:\nBut for the certain knowledge of that truth\nI put you o'er to heaven and to my mother:\nOf that I doubt, as all men's children may.\n\nQUEEN ELINOR\n\nOut on thee, rude man! thou dost shame thy mother\nAnd wound her honour with this diffidence.\n\nBASTARD\n\nI, madam? no, I have no reason for it;\nThat is my brother's plea and none of mine;\nThe which if he can prove, a' pops me out\nAt least from fair five hundred pound a year:\nHeaven guard my mother's honour and my land!\n\nKING JOHN\n\nA good blunt fellow. Why, being younger born,\nDoth he lay claim to thine inheritance?\n\nBASTARD\n\nI know not why, except to get the land.\nBut once he slander'd me with bastardy:\nBut whether I be as true begot or no,\nThat still I lay upon my mother's head,\nBut that I am as well begot, my liege,--\nFair fall the bones that took the pains ...
#   "metadata": {},
#   "enriched_text": {
#     "status": "OK",
#     "warningMessage": "truncated-oversized-text-content",
#     "language": "english",
#     "docSentiment": {
#       "type": "negative",
#       "score": -0.109708,
#       "mixed": true
#     },
#     "concepts": [
#       {
#         "text": "Philip II of France",
#         "relevance": 0.966415,
#         "dbpedia": "http://dbpedia.org/resource/Philip_II_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.068m5",
#         "yago": "http://yago-knowledge.org/resource/Philip_II_of_France"
#       },
#       {
#         "text": "John of England",
#         "relevance": 0.914807,
#         "dbpedia": "http://dbpedia.org/resource/John_of_England",
#         "yago": "http://yago-knowledge.org/resource/John_of_England"
#       },
#       {
#         "text": "Philip II of Spain",
#         "relevance": 0.793564,
#         "dbpedia": "http://dbpedia.org/resource/Philip_II_of_Spain",
#         "freebase": "http://rdf.freebase.com/ns/m.0f6fz",
#         "yago": "http://yago-knowledge.org/resource/Philip_II_of_Spain"
#       },
#       {
#         "text": "House of Capet",
#         "relevance": 0.756708,
#         "dbpedia": "http://dbpedia.org/resource/House_of_Capet",
#         "freebase": "http://rdf.freebase.com/ns/m.05mxmt",
#         "yago": "http://yago-knowledge.org/resource/House_of_Capet"
#       },
#       {
#         "text": "Louis VIII of France",
#         "relevance": 0.717723,
#         "dbpedia": "http://dbpedia.org/resource/Louis_VIII_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kp62",
#         "yago": "http://yago-knowledge.org/resource/Louis_VIII_of_France"
#       },
#       {
#         "text": "Philip IV of France",
#         "relevance": 0.687205,
#         "dbpedia": "http://dbpedia.org/resource/Philip_IV_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0k7mm",
#         "yago": "http://yago-knowledge.org/resource/Philip_IV_of_France"
#       },
#       {
#         "text": "Thou",
#         "relevance": 0.66748,
#         "dbpedia": "http://dbpedia.org/resource/Thou",
#         "freebase": "http://rdf.freebase.com/ns/m.01j4wt",
#         "yago": "http://yago-knowledge.org/resource/Thou"
#       },
#       {
#         "text": "Philip I of France",
#         "relevance": 0.655121,
#         "dbpedia": "http://dbpedia.org/resource/Philip_I_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kg_6",
#         "yago": "http://yago-knowledge.org/resource/Philip_I_of_France"
#       },
#       {
#         "text": "Louis VI of France",
#         "relevance": 0.618934,
#         "dbpedia": "http://dbpedia.org/resource/Louis_VI_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kg1d",
#         "yago": "http://yago-knowledge.org/resource/Louis_VI_of_France"
#       },
#       {
#         "text": "French monarchs",
#         "relevance": 0.610358,
#         "dbpedia": "http://dbpedia.org/resource/French_monarchs"
#       },
#       {
#         "text": "Philip V of France",
#         "relevance": 0.584052,
#         "dbpedia": "http://dbpedia.org/resource/Philip_V_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0khfr",
#         "yago": "http://yago-knowledge.org/resource/Philip_V_of_France"
#       },
#       {
#         "text": "Arthur I, Duke of Brittany",
#         "relevance": 0.576688,
#         "dbpedia": "http://dbpedia.org/resource/Arthur_I,_Duke_of_Brittany",
#         "freebase": "http://rdf.freebase.com/ns/m.018tz_",
#         "yago": "http://yago-knowledge.org/resource/Arthur_I,_Duke_of_Brittany"
#       },
#       {
#         "text": "Philip III of France",
#         "relevance": 0.558061,
#         "dbpedia": "http://dbpedia.org/resource/Philip_III_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kg_q",
#         "yago": "http://yago-knowledge.org/resource/Philip_III_of_France"
#       },
#       {
#         "text": "Henry VI of England",
#         "relevance": 0.528776,
#         "dbpedia": "http://dbpedia.org/resource/Henry_VI_of_England",
#         "freebase": "http://rdf.freebase.com/ns/m.0cmz2",
#         "yago": "http://yago-knowledge.org/resource/Henry_VI_of_England"
#       },
#       {
#         "text": "Louis VII of France",
#         "relevance": 0.528617,
#         "dbpedia": "http://dbpedia.org/resource/Louis_VII_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0czd0",
#         "yago": "http://yago-knowledge.org/resource/Louis_VII_of_France"
#       },
#       {
#         "text": "Richard I of England",
#         "relevance": 0.513018,
#         "dbpedia": "http://dbpedia.org/resource/Richard_I_of_England",
#         "freebase": "http://rdf.freebase.com/ns/m.06kq_",
#         "yago": "http://yago-knowledge.org/resource/Richard_I_of_England"
#       },
#       {
#         "text": "Kingdom of England",
#         "relevance": 0.474988,
#         "dbpedia": "http://dbpedia.org/resource/Kingdom_of_England",
#         "freebase": "http://rdf.freebase.com/ns/m.024pcx",
#         "yago": "http://yago-knowledge.org/resource/Kingdom_of_England"
#       },
#       {
#         "text": "Henry I of France",
#         "relevance": 0.469108,
#         "dbpedia": "http://dbpedia.org/resource/Henry_I_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kfxk",
#         "yago": "http://yago-knowledge.org/resource/Henry_I_of_France"
#       },
#       {
#         "text": "Philip VI of France",
#         "relevance": 0.460219,
#         "dbpedia": "http://dbpedia.org/resource/Philip_VI_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0k9ld",
#         "yago": "http://yago-knowledge.org/resource/Philip_VI_of_France"
#       },
#       {
#         "text": "The Life and Death of King John",
#         "relevance": 0.444751,
#         "dbpedia": "http://dbpedia.org/resource/The_Life_and_Death_of_King_John",
#         "freebase": "http://rdf.freebase.com/ns/m.0hnj0"
#       },
#       {
#         "text": "Louis X of France",
#         "relevance": 0.432978,
#         "dbpedia": "http://dbpedia.org/resource/Louis_X_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0kg99",
#         "yago": "http://yago-knowledge.org/resource/Louis_X_of_France"
#       },
#       {
#         "text": "King Philip's War",
#         "relevance": 0.424037,
#         "dbpedia": "http://dbpedia.org/resource/King_Philip's_War",
#         "freebase": "http://rdf.freebase.com/ns/m.01tg0c",
#         "yago": "http://yago-knowledge.org/resource/King_Philip's_War"
#       },
#       {
#         "text": "Louis XIII of France",
#         "relevance": 0.423236,
#         "dbpedia": "http://dbpedia.org/resource/Louis_XIII_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0k6xj",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwR9aFJwpEbGdrcN5Y29ycA",
#         "yago": "http://yago-knowledge.org/resource/Louis_XIII_of_France"
#       },
#       {
#         "text": "Louis IX of France",
#         "relevance": 0.41688,
#         "dbpedia": "http://dbpedia.org/resource/Louis_IX_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.04pv3",
#         "yago": "http://yago-knowledge.org/resource/Louis_IX_of_France"
#       },
#       {
#         "text": "Early Modern English",
#         "relevance": 0.414929,
#         "dbpedia": "http://dbpedia.org/resource/Early_Modern_English",
#         "freebase": "http://rdf.freebase.com/ns/m.03yb_1",
#         "yago": "http://yago-knowledge.org/resource/Early_Modern_English"
#       },
#       {
#         "text": "Louis XVI of France",
#         "relevance": 0.401512,
#         "dbpedia": "http://dbpedia.org/resource/Louis_XVI_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0dj9w",
#         "opencyc": "http://sw.opencyc.org/concept/Mx4rwUnqopwpEbGdrcN5Y29ycA",
#         "yago": "http://yago-knowledge.org/resource/Louis_XVI_of_France"
#       },
#       {
#         "text": "Charles IV of France",
#         "relevance": 0.397813,
#         "dbpedia": "http://dbpedia.org/resource/Charles_IV_of_France",
#         "freebase": "http://rdf.freebase.com/ns/m.0khf8",
#         "yago": "http://yago-knowledge.org/resource/Charles_IV_of_France"
#       },
#       {
#         "text": "Mother",
#         "relevance": 0.397256,
#         "dbpedia": "http://dbpedia.org/resource/Mother",
#         "freebase": "http://rdf.freebase.com/ns/m.0lbxz"
#       },
#       {
#         "text": "Benjamin Church",
#         "relevance": 0.393678,
#         "dbpedia": "http://dbpedia.org/resource/Benjamin_Church_(military_officer)",
#         "freebase": "http://rdf.freebase.com/ns/m.05pkrg",
#         "yago": "http://yago-knowledge.org/resource/Benjamin_Church_(military_officer)"
#       },
#       {
#         "text": "Mary I of England",
#         "relevance": 0.39361,
#         "dbpedia": "http://dbpedia.org/resource/Mary_I_of_England",
#         "freebase": "http://rdf.freebase.com/ns/m.056j9",
#         "yago": "http://yago-knowledge.org/resource/Mary_I_of_England"
#       }
#     ],
#     "entities": [
#       {
#         "type": "Person",
#         "relevance": 0.841569,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.887908,
#           "mixed": false
#         },
#         "count": 42,
#         "text": "KING PHILIP"
#       },
#       {
#         "type": "Country",
#         "relevance": 0.669626,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.0848756,
#           "mixed": true
#         },
#         "count": 43,
#         "text": "France",
#         "disambiguated": {
#           "name": "July Monarchy",
#           "dbpedia": "http://dbpedia.org/resource/July_Monarchy",
#           "freebase": "http://rdf.freebase.com/ns/m.020v1q",
#           "yago": "http://yago-knowledge.org/resource/July_Monarchy"
#         }
#       },
#       {
#         "type": "Country",
#         "relevance": 0.551717,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.345574,
#           "mixed": true
#         },
#         "count": 28,
#         "text": "England"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.480765,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.419729,
#           "mixed": false
#         },
#         "count": 20,
#         "text": "QUEEN ELINOR"
#       },
#       {
#         "type": "Country",
#         "relevance": 0.453363,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 19,
#         "text": "AUSTRIA"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.452309,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.704448,
#           "mixed": false
#         },
#         "count": 14,
#         "text": "uncle John"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.391631,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.460206,
#           "mixed": false
#         },
#         "count": 13,
#         "text": "Arthur"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.373106,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.122107,
#           "mixed": true
#         },
#         "count": 22,
#         "text": "Sir Robert",
#         "disambiguated": {
#           "name": "Bob Kerslake",
#           "dbpedia": "http://dbpedia.org/resource/Bob_Kerslake",
#           "freebase": "http://rdf.freebase.com/ns/m.0289vc5",
#           "yago": "http://yago-knowledge.org/resource/Bob_Kerslake"
#         }
#       },
#       {
#         "type": "Organization",
#         "relevance": 0.344543,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.6235,
#           "mixed": false
#         },
#         "count": 8,
#         "text": "Lords",
#         "disambiguated": {
#           "name": "Lords Feoffees",
#           "dbpedia": "http://dbpedia.org/resource/Lords_Feoffees",
#           "freebase": "http://rdf.freebase.com/ns/m.09bgyt",
#           "yago": "http://yago-knowledge.org/resource/Lords_Feoffees"
#         }
#       },
#       {
#         "type": "Person",
#         "relevance": 0.33709,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.604047,
#           "mixed": false
#         },
#         "count": 7,
#         "text": "O Lewis"
#       },
#       {
#         "type": "City",
#         "relevance": 0.328747,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 8,
#         "text": "Angiers",
#         "disambiguated": {
#           "subType": [],
#           "name": "Angers",
#           "website": "http://www.angers.fr/",
#           "dbpedia": "http://dbpedia.org/resource/Angers",
#           "freebase": "http://rdf.freebase.com/ns/m.0l4lj",
#           "geonames": "http://sws.geonames.org/3037656/"
#         }
#       },
#       {
#         "type": "Person",
#         "relevance": 0.321398,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 7,
#         "text": "Lady Blanch"
#       },
#       {
#         "type": "Company",
#         "relevance": 0.318943,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 8,
#         "text": "BLANCH"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.313857,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 4,
#         "text": "King John"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.309683,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 8,
#         "text": "Robert Faulconbridge"
#       },
#       {
#         "type": "GeographicFeature",
#         "relevance": 0.308585,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.460254,
#           "mixed": false
#         },
#         "count": 1,
#         "text": "King John"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.307736,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.593187,
#           "mixed": false
#         },
#         "count": 3,
#         "text": "Lady Constance"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.302012,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.0157989,
#           "mixed": true
#         },
#         "count": 8,
#         "text": "sir Richard"
#       },
#       {
#         "type": "City",
#         "relevance": 0.290489,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.490422,
#           "mixed": false
#         },
#         "count": 4,
#         "text": "Touraine",
#         "disambiguated": {
#           "subType": [
#             "AdministrativeDivision",
#             "GovernmentalJurisdiction"
#           ],
#           "name": "Gatineau",
#           "geo": "45.483333333333334,-75.65",
#           "website": "http://www.ville.gatineau.qc.ca/",
#           "dbpedia": "http://dbpedia.org/resource/Gatineau",
#           "freebase": "http://rdf.freebase.com/ns/m.0pml7",
#           "geonames": "http://sws.geonames.org/5959976/",
#           "yago": "http://yago-knowledge.org/resource/Gatineau"
#         }
#       },
#       {
#         "type": "StateOrCounty",
#         "relevance": 0.276005,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 4,
#         "text": "Maine"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.267458,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 5,
#         "text": "Angiers"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.266915,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 4,
#         "text": "Sirrah"
#       },
#       {
#         "type": "City",
#         "relevance": 0.258497,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.578167,
#           "mixed": false
#         },
#         "count": 2,
#         "text": "Faulconbridge",
#         "disambiguated": {
#           "subType": [],
#           "name": "Faulconbridge, New South Wales",
#           "geo": "-33.68333333333333,150.53333333333333",
#           "dbpedia": "http://dbpedia.org/resource/Faulconbridge,_New_South_Wales",
#           "freebase": "http://rdf.freebase.com/ns/m.04qc7_",
#           "geonames": "http://sws.geonames.org/2166826/",
#           "yago": "http://yago-knowledge.org/resource/Faulconbridge,_New_South_Wales"
#         }
#       },
#       {
#         "type": "Person",
#         "relevance": 0.258445,
#         "sentiment": {
#           "type": "positive",
#           "score": 0.668156,
#           "mixed": false
#         },
#         "count": 1,
#         "text": "King Richard Coeur-de-lion"
#       },
#       {
#         "type": "City",
#         "relevance": 0.257927,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 5,
#         "text": "SALISBURY",
#         "disambiguated": {
#           "subType": [],
#           "name": "Salisbury, Herkimer County, New York",
#           "geo": "43.134166666666665,-74.82416666666667",
#           "dbpedia": "http://dbpedia.org/resource/Salisbury,_Herkimer_County,_New_York",
#           "freebase": "http://rdf.freebase.com/ns/m.0y0kv",
#           "yago": "http://yago-knowledge.org/resource/Salisbury,_Herkimer_County,_New_York"
#         }
#       },
#       {
#         "type": "Person",
#         "relevance": 0.255222,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 4,
#         "text": "Exeunt CHATILLON"
#       },
#       {
#         "type": "City",
#         "relevance": 0.252653,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 3,
#         "text": "Anjou",
#         "disambiguated": {
#           "subType": [],
#           "name": "Anjou, Quebec",
#           "geo": "45.6,-73.53333333333333",
#           "website": "http://ville.montreal.qc.ca/portal/page?_pageid=2238,2889924&_dad=portal&_schema=PORTAL",
#           "dbpedia": "http://dbpedia.org/resource/Anjou,_Quebec",
#           "freebase": "http://rdf.freebase.com/ns/m.078l1s",
#           "geonames": "http://sws.geonames.org/5885369/",
#           "yago": "http://yago-knowledge.org/resource/Anjou,_Quebec"
#         }
#       },
#       {
#         "type": "Company",
#         "relevance": 0.24217,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 7,
#         "text": "CHATILLON"
#       },
#       {
#         "type": "City",
#         "relevance": 0.240866,
#         "sentiment": {
#           "type": "negative",
#           "score": -0.60004,
#           "mixed": false
#         },
#         "count": 3,
#         "text": "Bretagne"
#       },
#       {
#         "type": "Person",
#         "relevance": 0.240559,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "count": 1,
#         "text": "Arthur Plantagenet",
#         "disambiguated": {
#           "subType": [
#             "ChivalricOrderMember"
#           ],
#           "name": "Arthur Plantagenet, 1st Viscount Lisle",
#           "dbpedia": "http://dbpedia.org/resource/Arthur_Plantagenet,_1st_Viscount_Lisle",
#           "freebase": "http://rdf.freebase.com/ns/m.03wfdf",
#           "yago": "http://yago-knowledge.org/resource/Arthur_Plantagenet,_1st_Viscount_Lisle"
#         }
#       }
#     ],
#     "relations": [
#       {
#         "sentence": " Now, say, Chatillon, what would France with us?",
#         "subject": {
#           "text": "Chatillon",
#           "entities": [
#             {
#               "type": "Company",
#               "text": "CHATILLON"
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Chatillon"
#             }
#           ]
#         },
#         "action": {
#           "text": "say",
#           "lemmatized": "say",
#           "verb": {
#             "text": "say",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "what would France with us",
#           "entities": [
#             {
#               "type": "Country",
#               "text": "France",
#               "disambiguated": {
#                 "name": "July Monarchy",
#                 "dbpedia": "http://dbpedia.org/resource/July_Monarchy",
#                 "freebase": "http://rdf.freebase.com/ns/m.020v1q",
#                 "yago": "http://yago-knowledge.org/resource/July_Monarchy"
#               }
#             },
#             {
#               "type": "Country",
#               "text": "us",
#               "disambiguated": {
#                 "subType": [
#                   "Location",
#                   "Region",
#                   "AdministrativeDivision",
#                   "Country",
#                   "GovernmentalJurisdiction",
#                   "FilmEditor"
#                 ],
#                 "name": "United States",
#                 "website": "http://www.usa.gov/",
#                 "dbpedia": "http://dbpedia.org/resource/United_States",
#                 "ciaFactbook": "http://www4.wiwiss.fu-berlin.de/factbook/resource/United_States",
#                 "freebase": "http://rdf.freebase.com/ns/m.09c7w0",
#                 "opencyc": "http://sw.opencyc.org/concept/Mx4rvVikKpwpEbGdrcN5Y29ycA",
#                 "yago": "http://yago-knowledge.org/resource/United_States"
#               }
#             }
#           ],
#           "keywords": [
#             {
#               "text": "France"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Arthur Plantagenet, lays most lawful claim",
#         "subject": {
#           "text": "Arthur Plantagenet,",
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Arthur Plantagenet",
#               "disambiguated": {
#                 "subType": [
#                   "ChivalricOrderMember"
#                 ],
#                 "name": "Arthur Plantagenet, 1st Viscount Lisle",
#                 "dbpedia": "http://dbpedia.org/resource/Arthur_Plantagenet,_1st_Viscount_Lisle",
#                 "freebase": "http://rdf.freebase.com/ns/m.03wfdf",
#                 "yago": "http://yago-knowledge.org/resource/Arthur_Plantagenet,_1st_Viscount_Lisle"
#               }
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Arthur Plantagenet"
#             }
#           ]
#         },
#         "action": {
#           "text": "lays",
#           "lemmatized": "lay",
#           "verb": {
#             "text": "lay",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "most lawful claim",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.647557,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "lawful claim"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Desiring thee to lay aside the sword",
#         "subject": {
#           "text": "thee",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.680185,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "thee"
#             }
#           ]
#         },
#         "action": {
#           "text": "Desiring",
#           "lemmatized": "Desiring",
#           "verb": {
#             "text": "Desiring",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "to lay aside the sword",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.570955,
#             "mixed": false
#           },
#           "sentimentFromSubject": {
#             "type": "positive",
#             "score": 0.692039,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "sword"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " And put these same into young Arthur's hand,",
#         "subject": {
#           "text": "these same"
#         },
#         "action": {
#           "text": "put",
#           "lemmatized": "put",
#           "verb": {
#             "text": "put",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "into young Arthur's hand",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.454639,
#             "mixed": false
#           },
#           "entities": [
#             {
#               "type": "Person",
#               "text": "Arthur"
#             }
#           ],
#           "keywords": [
#             {
#               "text": "young Arthur"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " What follows if we disallow of this?",
#         "subject": {
#           "text": "we"
#         },
#         "action": {
#           "text": "disallow",
#           "lemmatized": "disallow",
#           "verb": {
#             "text": "disallow",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "of this",
#           "sentimentFromSubject": {
#             "type": "negative",
#             "score": -0.458156,
#             "mixed": false
#           }
#         }
#       },
#       {
#         "sentence": " Here have we war for war and blood for blood,",
#         "subject": {
#           "text": "we war for war and blood for blood,",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.641521,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "blood"
#             },
#             {
#               "text": "war"
#             }
#           ]
#         },
#         "action": {
#           "text": "have",
#           "lemmatized": "have",
#           "verb": {
#             "text": "have",
#             "tense": "present"
#           }
#         },
#         "location": {
#           "text": "Here"
#         }
#       },
#       {
#         "sentence": " Here have we war for war and blood for blood,",
#         "subject": {
#           "text": "we"
#         },
#         "action": {
#           "text": "war",
#           "lemmatized": "war",
#           "verb": {
#             "text": "war",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "for war and blood for blood",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.606259,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "blood"
#             },
#             {
#               "text": "war"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Then take my king's defiance from my mouth,",
#         "subject": {
#           "text": "my king",
#           "keywords": [
#             {
#               "text": "king"
#             }
#           ]
#         },
#         "action": {
#           "text": "take",
#           "lemmatized": "take",
#           "verb": {
#             "text": "take",
#             "tense": "present"
#           }
#         }
#       },
#       {
#         "sentence": " For ere thou canst report I will be there,",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "will be",
#           "lemmatized": "will be",
#           "verb": {
#             "text": "be",
#             "tense": "future"
#           }
#         },
#         "location": {
#           "text": "there"
#         }
#       },
#       {
#         "sentence": " An honourable conduct let him have:",
#         "subject": {
#           "text": "An honourable conduct",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.539005,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "honourable conduct"
#             }
#           ]
#         },
#         "action": {
#           "text": "let",
#           "lemmatized": "let",
#           "verb": {
#             "text": "let",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "him"
#         }
#       },
#       {
#         "sentence": " Pembroke, look to 't.",
#         "subject": {
#           "text": "Pembroke",
#           "entities": [
#             {
#               "type": "City",
#               "text": "PEMBROKE",
#               "disambiguated": {
#                 "subType": [
#                   "Location",
#                   "CityTown"
#                 ],
#                 "name": "Pembroke, Maine",
#                 "geo": "44.95361111111111,-67.16194444444444",
#                 "dbpedia": "http://dbpedia.org/resource/Pembroke,_Maine",
#                 "freebase": "http://rdf.freebase.com/ns/m.0tsr0",
#                 "yago": "http://yago-knowledge.org/resource/Pembroke,_Maine"
#               }
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Pembroke"
#             }
#           ]
#         },
#         "action": {
#           "text": "look",
#           "lemmatized": "look",
#           "verb": {
#             "text": "look",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "to 't",
#           "sentimentFromSubject": {
#             "type": "positive",
#             "score": 0.475244,
#             "mixed": false
#           }
#         }
#       },
#       {
#         "sentence": " What now, my son! have I not ever said",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "have",
#           "lemmatized": "have",
#           "verb": {
#             "text": "have",
#             "tense": "present"
#           }
#         }
#       },
#       {
#         "sentence": " What now, my son! have I not ever said",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "said",
#           "lemmatized": "say",
#           "verb": {
#             "text": "say",
#             "tense": "past",
#             "negated": "1"
#           }
#         },
#         "object": {
#           "text": "What now, my son",
#           "keywords": [
#             {
#               "text": "son"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Till she had kindled France and all the world,",
#         "subject": {
#           "text": "she"
#         },
#         "action": {
#           "text": "had kindled",
#           "lemmatized": "have kindle",
#           "verb": {
#             "text": "kindle",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "France",
#           "entities": [
#             {
#               "type": "Country",
#               "text": "France",
#               "disambiguated": {
#                 "subType": [
#                   "Location",
#                   "Region",
#                   "AdministrativeDivision",
#                   "Country",
#                   "GovernmentalJurisdiction",
#                   "FilmDirector"
#                 ],
#                 "name": "France",
#                 "geo": "47.0,2.0",
#                 "website": "http://www.service-public.fr/etranger/english.html",
#                 "dbpedia": "http://dbpedia.org/resource/France",
#                 "ciaFactbook": "http://www4.wiwiss.fu-berlin.de/factbook/resource/France",
#                 "freebase": "http://rdf.freebase.com/ns/m.0f8l9c",
#                 "opencyc": "http://sw.opencyc.org/concept/Mx4rvVj6EJwpEbGdrcN5Y29ycA",
#                 "yago": "http://yago-knowledge.org/resource/France"
#               }
#             }
#           ],
#           "keywords": [
#             {
#               "text": "France"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " This might have been prevented and made whole",
#         "subject": {
#           "text": "This"
#         },
#         "action": {
#           "text": "made",
#           "lemmatized": "make",
#           "verb": {
#             "text": "make",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "whole"
#         }
#       },
#       {
#         "sentence": " Or else it must go wrong with you and me:",
#         "subject": {
#           "text": "it"
#         },
#         "action": {
#           "text": "must go",
#           "lemmatized": "must go",
#           "verb": {
#             "text": "go",
#             "tense": "future"
#           }
#         },
#         "object": {
#           "text": "wrong",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.741235,
#             "mixed": false
#           }
#         }
#       },
#       {
#         "sentence": " My liege, here is the strangest controversy",
#         "subject": {
#           "text": "My liege, here",
#           "keywords": [
#             {
#               "text": "liege"
#             }
#           ]
#         },
#         "action": {
#           "text": "is",
#           "lemmatized": "be",
#           "verb": {
#             "text": "be",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "the strangest controversy",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.814215,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "strangest controversy"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " That e'er I heard: shall I produce the men?",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "produce",
#           "lemmatized": "produce",
#           "verb": {
#             "text": "produce",
#             "tense": "future"
#           }
#         },
#         "object": {
#           "text": "the men",
#           "sentimentFromSubject": {
#             "type": "positive",
#             "score": 0.484882,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "men"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Of Coeur-de-lion knighted in the field.",
#         "subject": {
#           "text": "Coeur-de-lion",
#           "keywords": [
#             {
#               "text": "Coeur-de-lion"
#             }
#           ]
#         },
#         "action": {
#           "text": "knighted",
#           "lemmatized": "knight",
#           "verb": {
#             "text": "knight",
#             "tense": "past"
#           }
#         },
#         "location": {
#           "text": "in the field"
#         }
#       },
#       {
#         "sentence": " That is well known; and, as I think, one father:",
#         "subject": {
#           "text": "That"
#         },
#         "action": {
#           "text": "is",
#           "lemmatized": "be",
#           "verb": {
#             "text": "be",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "well known",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.461361,
#             "mixed": false
#           }
#         }
#       },
#       {
#         "sentence": " Out on thee, rude man! thou dost shame thy mother",
#         "subject": {
#           "text": "shame",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.769909,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "shame"
#             }
#           ]
#         },
#         "action": {
#           "text": "dost",
#           "lemmatized": "dost",
#           "verb": {
#             "text": "dost",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "thy mother",
#           "sentiment": {
#             "type": "positive",
#             "score": 0.560203,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "thy mother"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " And wound her honour with this diffidence.",
#         "subject": {
#           "text": "her honour",
#           "keywords": [
#             {
#               "text": "honour"
#             }
#           ]
#         },
#         "action": {
#           "text": "wound",
#           "lemmatized": "wind",
#           "verb": {
#             "text": "wind",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "with this diffidence",
#           "keywords": [
#             {
#               "text": "diffidence"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " I, madam? no, I have no reason for it;",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "have",
#           "lemmatized": "have",
#           "verb": {
#             "text": "have",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "no reason for it",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.754472,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "reason"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " That is my brother's plea and none of mine;",
#         "subject": {
#           "text": "That"
#         },
#         "action": {
#           "text": "is",
#           "lemmatized": "be",
#           "verb": {
#             "text": "be",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "my brother's plea and none of mine",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.915734,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "plea"
#             },
#             {
#               "text": "brother"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Doth he lay claim to thine inheritance?",
#         "subject": {
#           "text": "he"
#         },
#         "action": {
#           "text": "lay",
#           "lemmatized": "lie",
#           "verb": {
#             "text": "lie",
#             "tense": "past"
#           }
#         },
#         "object": {
#           "text": "claim to thine inheritance",
#           "keywords": [
#             {
#               "text": "claim"
#             },
#             {
#               "text": "inheritance"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " Doth he lay claim to thine inheritance?",
#         "subject": {
#           "text": "he"
#         },
#         "action": {
#           "text": "to thine",
#           "lemmatized": "to thine",
#           "verb": {
#             "text": "thine",
#             "tense": "future"
#           }
#         },
#         "object": {
#           "text": "inheritance",
#           "keywords": [
#             {
#               "text": "inheritance"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " I know not why, except to get the land.",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "know",
#           "lemmatized": "know",
#           "verb": {
#             "text": "know",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "not why, except to get the land",
#           "sentiment": {
#             "type": "negative",
#             "score": -0.439279,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "land"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " I know not why, except to get the land.",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "to get",
#           "lemmatized": "to get",
#           "verb": {
#             "text": "get",
#             "tense": "future"
#           }
#         },
#         "object": {
#           "text": "the land",
#           "keywords": [
#             {
#               "text": "land"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " But once he slander'd me with bastardy:",
#         "subject": {
#           "text": "he"
#         },
#         "action": {
#           "text": "slander",
#           "lemmatized": "slander",
#           "verb": {
#             "text": "slander",
#             "tense": "present"
#           }
#         },
#         "object": {
#           "text": "with bastardy",
#           "sentimentFromSubject": {
#             "type": "negative",
#             "score": -0.77074,
#             "mixed": false
#           },
#           "keywords": [
#             {
#               "text": "bastardy"
#             }
#           ]
#         }
#       },
#       {
#         "sentence": " That still I lay upon my mother's head,",
#         "subject": {
#           "text": "I"
#         },
#         "action": {
#           "text": "lay",
#           "lemmatized": "lie",
#           "verb": {
#             "text": "lie",
#             "tense": "past"
#           }
#         }
#       }
#     ],
#     "taxonomy": [
#       {
#         "label": "/travel/tourist destinations/france",
#         "score": 0.589227,
#         "confident": false
#       },
#       {
#         "label": "/science/social science/history/medieval history",
#         "score": 0.500512,
#         "confident": false
#       },
#       {
#         "label": "/family and parenting/children",
#         "score": 0.49403,
#         "confident": false
#       }
#     ],
#     "keywords": [
#       {
#         "relevance": 0.982432,
#         "sentiment": {
#           "score": 0.555817,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "king john"
#       },
#       {
#         "relevance": 0.817777,
#         "sentiment": {
#           "score": 0.412744,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "QUEEN ELINOR"
#       },
#       {
#         "relevance": 0.690969,
#         "sentiment": {
#           "score": -0.65183,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "bastard"
#       },
#       {
#         "relevance": 0.654041,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.166815,
#           "type": "positive"
#         },
#         "text": "sir robert"
#       },
#       {
#         "relevance": 0.639647,
#         "sentiment": {
#           "mixed": true,
#           "score": -0.064096,
#           "type": "negative"
#         },
#         "text": "France"
#       },
#       {
#         "relevance": 0.638287,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.250339,
#           "type": "positive"
#         },
#         "text": "philip"
#       },
#       {
#         "relevance": 0.636941,
#         "sentiment": {
#           "score": 0.371875,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "thou thy desire"
#       },
#       {
#         "relevance": 0.618492,
#         "sentiment": {
#           "score": 0.557092,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "old sir Robert"
#       },
#       {
#         "relevance": 0.617086,
#         "sentiment": {
#           "score": 0.452636,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "hast thou"
#       },
#       {
#         "relevance": 0.612143,
#         "sentiment": {
#           "score": -0.600452,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "thou art"
#       },
#       {
#         "relevance": 0.59981,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "thou unreverend boy"
#       },
#       {
#         "relevance": 0.599412,
#         "sentiment": {
#           "mixed": true,
#           "score": -0.0998358,
#           "type": "negative"
#         },
#         "text": "son"
#       },
#       {
#         "relevance": 0.599351,
#         "sentiment": {
#           "score": -0.420019,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "art thou"
#       },
#       {
#         "relevance": 0.598999,
#         "sentiment": {
#           "score": 0.457454,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "constance"
#       },
#       {
#         "relevance": 0.593668,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.0511407,
#           "type": "positive"
#         },
#         "text": "England"
#       },
#       {
#         "relevance": 0.592631,
#         "sentiment": {
#           "mixed": true,
#           "score": -0.401102,
#           "type": "negative"
#         },
#         "text": "thy brother"
#       },
#       {
#         "relevance": 0.590425,
#         "sentiment": {
#           "score": 0.570155,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "right thou"
#       },
#       {
#         "relevance": 0.589835,
#         "sentiment": {
#           "score": -0.681349,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "Thou unadvised scold"
#       },
#       {
#         "relevance": 0.588918,
#         "sentiment": {
#           "score": -0.744992,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "Thou monstrous slanderer"
#       },
#       {
#         "relevance": 0.588855,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Thou monstrous injurer"
#       },
#       {
#         "relevance": 0.588082,
#         "sentiment": {
#           "score": -0.538782,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "thou hast misspoke"
#       },
#       {
#         "relevance": 0.587433,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.0686216,
#           "type": "positive"
#         },
#         "text": "thy son"
#       },
#       {
#         "relevance": 0.587341,
#         "sentiment": {
#           "score": -0.656377,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "thy bastard"
#       },
#       {
#         "relevance": 0.585724,
#         "sentiment": {
#           "score": 0.433941,
#           "type": "positive",
#           "mixed": false
#         },
#         "text": "I. KING JOHN"
#       },
#       {
#         "relevance": 0.583967,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.297967,
#           "type": "positive"
#         },
#         "text": "father"
#       },
#       {
#         "relevance": 0.583175,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.0111449,
#           "type": "positive"
#         },
#         "text": "mother"
#       },
#       {
#         "relevance": 0.582554,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "thou dost"
#       },
#       {
#         "relevance": 0.582327,
#         "sentiment": {
#           "mixed": true,
#           "score": 0.121962,
#           "type": "positive"
#         },
#         "text": "hath"
#       },
#       {
#         "relevance": 0.581653,
#         "sentiment": {
#           "score": -0.420019,
#           "type": "negative",
#           "mixed": false
#         },
#         "text": "fool art thou"
#       },
#       {
#         "relevance": 0.579756,
#         "sentiment": {
#           "type": "neutral",
#           "mixed": false
#         },
#         "text": "Thou cold-blooded slave"
#       }
#     ]
#   }
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**:    "docSentiment": {
#       "type": "negative",
#       "score": -0.109708,
#       "mixed": true
#     },
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**:
#  "text": "Philip II of France",
#  "relevance": 0.966415,
#
#  "text": "John of England",
#  "relevance": 0.914807,
#
#  "text": "Philip II of Spain",
#  "relevance": 0.793564,
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
#
# Watson did not do a good job breaking down relationships for these prose.  The only real relationship I found was below and it does seem reasonable:
#
# "sentence": " Now, say, Chatillon, what would France with us?"
#
# "subject": "Chatillon"
#
# "action": "say"
#
# "object": "what would France with us"
#
#
#
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Vega10")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# /home/cher/anaconda3/envs/aind/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The Vega10 colormap was deprecated in version 2.0. Use tab10 instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Shakespeare".

# %%
# Prepare a collection of documents to use

# fixed discovery_v1.py per github.com/watson-developer-cloud/python-sdk/pull/223/files

col, col_id = helper.fetch_object(discovery, "collection", "Shakespeare", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))

# Manually created "Story Chunks" collection from Watson Discovery Service Tool, per @angelmtenor work around instructions
# due to Watson Exception Code: 415

#col, col_id = helper.fetch_object(discovery, "collection","Story Chunks", environment_id=env_id)

print(json.dumps(col, indent=2))
# Out:
# Found collection: Shakespeare (168e22c0-83f1-49b0-b493-97a95d76f258)
# {
#   "collection_id": "168e22c0-83f1-49b0-b493-97a95d76f258",
#   "name": "Shakespeare",
#   "configuration_id": "00810bbe-4f8f-4b50-9ab9-ae61c74fa725",
#   "language": "en",
#   "status": "active",
#   "description": null,
#   "created": "2017-06-28T23:49:38.979Z",
#   "updated": "2017-06-28T23:49:38.979Z",
#   "document_counts": {
#     "available": 1500,
#     "processing": 0,
#     "failed": 65
#   },
#   "training_status": {
#     "data_updated": "",
#     "total_examples": 0,
#     "sufficient_label_diversity": false,
#     "processing": false,
#     "minimum_examples_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "notices": 0,
#     "minimum_queries_added": false
#   }
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Shakespeare" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                file_data=json.dumps({"text": p.get_text(strip=True)}),
                mime_type="application/json",
                metadata={"title": soup.title.get_text(strip=True)})
            doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: shakespeare/richard_ii.html
# Adding file: shakespeare/henry_v.html
# Adding file: shakespeare/henry_iv_p1.html
# Adding file: shakespeare/henry_vi_p3.html
# Adding file: shakespeare/john.html
# Adding file: shakespeare/henry_viii.html
# Adding file: shakespeare/henry_iv_p2.html
# Adding file: shakespeare/henry_vi_p1.html
# Adding file: shakespeare/richard_iii.html
# Adding file: shakespeare/henry_vi_p2.html
# Total 1554 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Shakespeare", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Shakespeare (168e22c0-83f1-49b0-b493-97a95d76f258)
# {
#   "collection_id": "168e22c0-83f1-49b0-b493-97a95d76f258",
#   "name": "Shakespeare",
#   "configuration_id": "00810bbe-4f8f-4b50-9ab9-ae61c74fa725",
#   "language": "en",
#   "status": "active",
#   "description": null,
#   "created": "2017-06-28T23:49:38.979Z",
#   "updated": "2017-06-28T23:49:38.979Z",
#   "document_counts": {
#     "available": 2986,
#     "processing": 0,
#     "failed": 131
#   },
#   "training_status": {
#     "data_updated": "",
#     "total_examples": 0,
#     "sufficient_label_diversity": false,
#     "processing": false,
#     "minimum_examples_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "notices": 0,
#     "minimum_queries_added": false
#   }
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': '168e22c0-83f1-49b0-b493-97a95d76f258.mappings.document._all.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'html', 'type': 'string'},
#   {'field': 'html.analyzer', 'type': 'english'},
#   {'field': 'metadata', 'type': 'nested'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'text.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.properties.docSentiment', 'type': 'nested'},
#   {'field': 'enriched_text.properties.entities', 'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.properties.language', 'type': 'string'},
#   {'field': 'enriched_text.properties.language.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.relations', 'type': 'nested'},
#   {'field': 'enriched_text.properties.status', 'type': 'string'},
#   {'field': 'enriched_text.properties.status.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy', 'type': 'nested'},
#   {'field': 'enriched_text.properties.warningMessage', 'type': 'string'},
#   {'field': 'enriched_text.properties.warningMessage.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.file_type', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.file_type.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.filename', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.filename.analyzer',
#    'type': 'english'},
#   {'field': 'extracted_metadata.properties.sha1', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.sha1.analyzer', 'type': 'english'},
#   {'field': 'extracted_metadata.properties.title', 'type': 'string'},
#   {'field': 'extracted_metadata.properties.title.analyzer', 'type': 'english'},
#   {'field': 'metadata.properties.title', 'type': 'string'},
#   {'field': 'metadata.properties.title.analyzer', 'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.geonames',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.geonames.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.musicBrainz.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.concepts.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.concepts.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.concepts.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.docSentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.docSentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.docSentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.count',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.quotations',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.relevance',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.sentence',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.sentence.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.taxonomy.properties.confident',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.taxonomy.properties.label.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.taxonomy.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.geonames',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.geonames.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.musicBrainz',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.musicBrainz.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.subType',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.subType.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.quotation',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.quotation.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.keywords.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.lemmatized.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.mixed',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.mixed.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.score',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.score.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.entities.properties.quotations.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.negated',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.negated.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.tense.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.action.properties.verb.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.score.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.sentimentFromSubject.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated',
#    'type': 'nested'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.keywords.properties.text.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.mixed',
#    'type': 'boolean'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.score',
#    'type': 'double'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.sentiment.properties.type.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.subType',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.subType.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.location.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.ciaFactbook',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.ciaFactbook.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.subType',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.subType.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.website',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.website.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.object.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.dbpedia.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.freebase.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.geo',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.geo.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.name.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.opencyc',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.opencyc.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.subType',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.subType.analyzer',
#    'type': 'english'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago',
#    'type': 'string'},
#   {'field': 'enriched_text.properties.relations.properties.subject.properties.entities.properties.disambiguated.properties.yago.analyzer',
#    'type': 'english'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.entities.text:Richard II",
        "return": "metadata.title,enriched_text.entities.text,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 33,
#   "results": [
#     {
#       "id": "c75205a4-db07-4b71-8a67-17c8d0437f48",
#       "score": 7.2642436,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Flourish. Exeunt KING RICHARD II and train"
#     },
#     {
#       "id": "e554b369-cba8-49ec-95be-19d0bef15ccc",
#       "score": 7.2642436,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Flourish. Exeunt KING RICHARD II and train"
#     },
#     {
#       "id": "097c986d-50f4-4a5c-b05b-ec16c2d68ae6",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "RICHARD II"
#           },
#           {
#             "text": "BAGOT"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Flourish. Exeunt KING RICHARD II, QUEEN, DUKE OF AUMERLE, BUSHY, GREEN, and BAGOT"
#     },
#     {
#       "id": "6709d94f-5ac7-44f0-bbc9-3655589fda1d",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Exeunt KING RICHARD II, some Lords, and a Guard"
#     },
#     {
#       "id": "404d50d5-eaa2-4eb3-9be8-f31b7c6d975f",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Enter KING RICHARD II and Guard"
#     },
#     {
#       "id": "f74ccbe3-50ed-43c3-8e25-897097e13566",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "RICHARD II"
#           },
#           {
#             "text": "BAGOT"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Flourish. Exeunt KING RICHARD II, QUEEN, DUKE OF AUMERLE, BUSHY, GREEN, and BAGOT"
#     },
#     {
#       "id": "cfdea5b0-9901-4aa3-9426-091e2e2daca7",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Exeunt KING RICHARD II, some Lords, and a Guard"
#     },
#     {
#       "id": "cc9e5d12-559c-43a7-a542-337d3e07b862",
#       "score": 5.448183,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Enter KING RICHARD II and Guard"
#     },
#     {
#       "id": "145344a2-6950-4601-b52e-cbf95789b536",
#       "score": 4.540152,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "YORK"
#           },
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Re-enter DUKE OF YORK, with KING RICHARD II, and Officers bearing the regalia"
#     },
#     {
#       "id": "f0b5a7b8-73d4-4bb2-8f59-a2e0665c8e4f",
#       "score": 4.540152,
#       "enriched_text": {
#         "entities": [
#           {
#             "text": "YORK"
#           },
#           {
#             "text": "KING RICHARD II"
#           }
#         ]
#       },
#       "metadata": {
#         "title": "Richard II: Entire Play"
#       },
#       "text": "Re-enter DUKE OF YORK, with KING RICHARD II, and Officers bearing the regalia"
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: Where an entity with the name 'Richard II' is found.
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text from the paragraph(s) returned.
#
# **A**:
#
# "text": "Flourish. Exeunt KING RICHARD II, QUEEN, DUKE OF AUMERLE, BUSHY, GREEN, and BAGOT"

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**:
#
# #who
# #what
# #where
#
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
#
# Where was Margaret born?
#
# Where was Henry VI held captive?
#
# Where was Richard of York exiled to?
#
# Where were King Edward's sons held captive?
#
# Where were Richard of York's forces defeated?
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "Shakespeare_history_plays")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: Shakespeare_history_plays (a1c18a7b-2fc0-4f95-ba59-e6e87cca77f3)
# {
#   "name": "Shakespeare_history_plays",
#   "created": "2017-06-30T18:03:34.189Z",
#   "updated": "2017-06-30T19:39:25.026Z",
#   "language": "en",
#   "metadata": null,
#   "description": "",
#   "workspace_id": "a1c18a7b-2fc0-4f95-ba59-e6e87cca77f3",
#   "status": "Available"
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'City',
#   'values': [{'value': 'Bardolph'},
#    {'value': 'AUVERGNE'},
#    {'value': 'Lancaster'},
#    {'value': 'NORTHUMBERLAND'},
#    {'value': 'Alarum. Enter YORK'},
#    {'value': 'NORFOLK'},
#    {'value': 'RUTLAND'},
#    {'value': 'Anjou'},
#    {'value': 'HASTINGS'},
#    {'value': 'England'},
#    {'value': 'BUCKINGHAM'},
#    {'value': 'Dauphin'},
#    {'value': 'Southampton'},
#    {'value': 'WESTMORELAND'},
#    {'value': 'Touraine'},
#    {'value': 'Hereford'},
#    {'value': 'Coventry'},
#    {'value': 'Paris'},
#    {'value': 'Gloucester'},
#    {'value': 'Bretagne'},
#    {'value': 'London'},
#    {'value': 'SUFFOLK'},
#    {'value': 'MONTAGUE'},
#    {'value': 'Ravenspurgh'},
#    {'value': 'Orleans'},
#    {'value': 'WARWICK'},
#    {'value': 'York'},
#    {'value': 'SOMERSET'},
#    {'value': 'Masham'},
#    {'value': 'Shrewsbury'},
#    {'value': 'Wiltshire'},
#    {'value': 'Agincourt'},
#    {'value': 'Worcester'},
#    {'value': 'BEDFORD'},
#    {'value': 'ELY'},
#    {'value': 'Gadshill'},
#    {'value': 'VERNON'},
#    {'value': 'SALISBURY'},
#    {'value': 'Angiers'},
#    {'value': 'ABERGAVENNY'},
#    {'value': 'EXETER'},
#    {'value': 'DORSET'},
#    {'value': 'Cambridge'},
#    {'value': 'CANTERBURY'},
#    {'value': 'Bagot'},
#    {'value': 'Faulconbridge'}]},
#  {'entity': 'Person',
#   'values': [{'value': 'Lord John'},
#    {'value': 'RICHARD PLANTAGENET'},
#    {'value': 'Edmund Mortimer'},
#    {'value': 'PRINCE EDWARD'},
#    {'value': 'Lieutenant BARDOLPH'},
#    {'value': 'Owen Glendower'},
#    {'value': 'SIR WALTER BLUNT'},
#    {'value': 'Julius Caesar'},
#    {'value': 'Lord Hastings'},
#    {'value': 'GEORGE'},
#    {'value': 'Edward Plantagenet'},
#    {'value': 'Harry'},
#    {'value': 'MARGARET JOURDAIN'},
#    {'value': 'Salisbury'},
#    {'value': 'JOHN'},
#    {'value': 'Lady Constance'},
#    {'value': 'LORD ROSS'},
#    {'value': 'Henry VIII'},
#    {'value': 'King Edward'},
#    {'value': 'Ned Poins'},
#    {'value': 'Duke Humphrey'},
#    {'value': 'lord chamberlain'},
#    {'value': 'Sir John Falstaff'},
#    {'value': 'John Falstaff'},
#    {'value': 'KING EDWARD IV'},
#    {'value': 'Henry VI'},
#    {'value': 'Sirrah'},
#    {'value': 'King Lewis'},
#    {'value': 'Exeunt King Henry'},
#    {'value': 'KING HENRY VI'},
#    {'value': 'Cardinal'},
#    {'value': 'Lo'},
#    {'value': 'King John'},
#    {'value': 'Francis'},
#    {'value': 'Robert Faulconbridge'},
#    {'value': 'QUEEN MARGARET'},
#    {'value': 'Master Poins'},
#    {'value': 'Hotspur'},
#    {'value': 'JACK FALSTAFF'},
#    {'value': 'Sir Henry Guildford'},
#    {'value': 'Sir Thomas Lovell'},
#    {'value': 'O Lewis'},
#    {'value': 'Orleans'},
#    {'value': 'PETER'},
#    {'value': 'KING HENRY IV'},
#    {'value': 'Edward King'},
#    {'value': 'Sir Gilbert Peck'},
#    {'value': 'sir Richard'},
#    {'value': 'Richard II'},
#    {'value': 'chamberlain'},
#    {'value': 'Lord Warwick'},
#    {'value': 'King Richard Coeur-de-lion'},
#    {'value': 'Henry King'},
#    {'value': 'Cardinal Campeius'},
#    {'value': 'PRINCE HENRY'},
#    {'value': 'ANNE'},
#    {'value': 'King Clothair'},
#    {'value': 'HENRY BOLINGBROKE'},
#    {'value': 'Sir John Hume'},
#    {'value': 'Dame Eleanor'},
#    {'value': 'King Henry'},
#    {'value': 'Nicholas Hopkins'},
#    {'value': 'Lord Aumerle'},
#    {'value': 'Exeunt CHATILLON'},
#    {'value': 'Noble earl'},
#    {'value': 'Exeunt CLARENCE'},
#    {'value': 'faint Henry'},
#    {'value': 'KING PHILIP'},
#    {'value': 'Harry Prince'},
#    {'value': 'John a Gaunt'},
#    {'value': 'Sir Robert'},
#    {'value': 'Robin Ostler'},
#    {'value': 'Sir John Sack'},
#    {'value': 'Reignier'},
#    {'value': 'King Richard'},
#    {'value': 'Angiers'},
#    {'value': 'Henry IV'},
#    {'value': 'QUEEN KATHARINE'},
#    {'value': 'Gloucester'},
#    {'value': 'Sirrah Jack'},
#    {'value': 'Richard Earl'},
#    {'value': 'Arthur'},
#    {'value': 'Sir Thomas'},
#    {'value': 'Harry Hereford'},
#    {'value': 'Falstaff'},
#    {'value': 'Harry Duke'},
#    {'value': 'Humphrey Duke'},
#    {'value': 'Lady Blanch'},
#    {'value': 'Lord Clifford'},
#    {'value': 'Harry Percy'},
#    {'value': 'Corporal NYM'},
#    {'value': 'Exeunt BARDOLPH'},
#    {'value': 'Lord marshal'},
#    {'value': 'Edward'},
#    {'value': 'QUEEN ELINOR'},
#    {'value': 'Harry King'},
#    {'value': 'KING HENRY V'},
#    {'value': 'Lord Talbot'},
#    {'value': 'Lord Bardolph'},
#    {'value': 'Exeunt PRINCE HENRY'},
#    {'value': 'Prince Hal'},
#    {'value': 'Henry Lord Scroop'},
#    {'value': 'Richard'},
#    {'value': 'Sir Walter'},
#    {'value': 'LORD WILLOUGHBY'},
#    {'value': 'Lord'},
#    {'value': 'CARDINAL WOLSEY'},
#    {'value': 'Arthur Plantagenet'},
#    {'value': 'Sir John'},
#    {'value': 'QUEEN ELIZABETH'},
#    {'value': 'Douglas'},
#    {'value': 'Thomas Mowbray'},
#    {'value': 'uncle John'},
#    {'value': 'Exeunt BUCKINGHAM'},
#    {'value': 'Richard Gloucester'},
#    {'value': 'York'},
#    {'value': 'JOAN LA PUCELLE'},
#    {'value': 'Lord marquess'},
#    {'value': 'Prince Harry'},
#    {'value': 'Poor Anne'},
#    {'value': 'Harry Monmouth'},
#    {'value': 'Prince Dauphin'},
#    {'value': 'Brakenbury'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Lords'},
#    {'value': 'Guard'},
#    {'value': 'Tower'},
#    {'value': 'TALBOT'},
#    {'value': 'BRAKENBURY'},
#    {'value': 'DUCHESS'},
#    {'value': 'lordship'},
#    {'value': 'ALENCON'},
#    {'value': 'cardinals'},
#    {'value': 'SANDS'}]},
#  {'entity': 'FieldTerminology',
#   'values': [{'value': 'the house'},
#    {'value': 'Duke of Buckingham'},
#    {'value': 'the queen'}]},
#  {'entity': 'Facility',
#   'values': [{'value': 'the Tower'},
#    {'value': 'Buckingham and Derby'},
#    {'value': 'BISHOP OF ELY'},
#    {'value': 'Lord John of Lancaster'},
#    {'value': 'Ely House'},
#    {'value': 'Lord of Lancaster'}]},
#  {'entity': 'Country',
#   'values': [{'value': 'Ireland'},
#    {'value': 'us'},
#    {'value': 'France'},
#    {'value': 'WALES'},
#    {'value': 'AUSTRIA'},
#    {'value': 'England'}]},
#  {'entity': 'Crime', 'values': [{'value': 'murder'}]},
#  {'entity': 'StateOrCounty',
#   'values': [{'value': 'WESTMORELAND'},
#    {'value': 'Somerset'},
#    {'value': 'NORTHUMBERLAND'},
#    {'value': 'Maine'},
#    {'value': 'SUFFOLK'}]},
#  {'entity': 'GeographicFeature',
#   'values': [{'value': 'Lord Northumberland'},
#    {'value': 'King John'},
#    {'value': 'Lord Sands'},
#    {'value': 'Lord Bardolph'},
#    {'value': 'King Pharamond'},
#    {'value': 'vale of Andren'}]},
#  {'entity': 'JobTitle',
#   'values': [{'value': 'ARCHBISHOP OF YORK'},
#    {'value': 'Earl of Worcester'},
#    {'value': 'BISHOPOF WINCHESTER'},
#    {'value': 'BISHOP OF WINCHESTER'},
#    {'value': 'Secretary'}]},
#  {'entity': 'HealthCondition',
#   'values': [{'value': 'Wounds'}, {'value': 'plague'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'BLANCH'}, {'value': 'CHATILLON'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "type": null,
#     "entity": "Facility",
#     "source": null,
#     "values": [
#       {
#         "value": "the Tower",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Buckingham and Derby",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BISHOP OF ELY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord John of Lancaster",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Ely House",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord of Lancaster",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "JobTitle",
#     "source": null,
#     "values": [
#       {
#         "value": "ARCHBISHOP OF YORK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Earl of Worcester",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BISHOPOF WINCHESTER",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BISHOP OF WINCHESTER",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Secretary",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "StateOrCounty",
#     "source": null,
#     "values": [
#       {
#         "value": "WESTMORELAND",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Somerset",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "NORTHUMBERLAND",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Maine",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SUFFOLK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "FieldTerminology",
#     "source": null,
#     "values": [
#       {
#         "value": "the house",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Duke of Buckingham",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "the queen",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "HealthCondition",
#     "source": null,
#     "values": [
#       {
#         "value": "Wounds",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "plague",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Country",
#     "source": null,
#     "values": [
#       {
#         "value": "Ireland",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "us",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "France",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "WALES",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "AUSTRIA",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "England",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "City",
#     "source": null,
#     "values": [
#       {
#         "value": "Bardolph",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "AUVERGNE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lancaster",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "NORTHUMBERLAND",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Alarum. Enter YORK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "NORFOLK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "RUTLAND",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Anjou",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "HASTINGS",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "England",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BUCKINGHAM",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Dauphin",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Southampton",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "WESTMORELAND",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Touraine",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Hereford",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Coventry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Paris",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Gloucester",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Bretagne",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "London",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SUFFOLK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "MONTAGUE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Ravenspurgh",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Orleans",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "WARWICK",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "York",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SOMERSET",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Masham",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Shrewsbury",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Wiltshire",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Agincourt",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Worcester",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BEDFORD",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "ELY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Gadshill",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "VERNON",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SALISBURY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Angiers",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "ABERGAVENNY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "EXETER",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "DORSET",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Cambridge",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "CANTERBURY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Bagot",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Faulconbridge",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Crime",
#     "source": null,
#     "values": [
#       {
#         "value": "murder",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "GeographicFeature",
#     "source": null,
#     "values": [
#       {
#         "value": "Lord Northumberland",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King John",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Sands",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Bardolph",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Pharamond",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "vale of Andren",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Organization",
#     "source": null,
#     "values": [
#       {
#         "value": "Lords",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Guard",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Tower",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "TALBOT",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "BRAKENBURY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "DUCHESS",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "lordship",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "ALENCON",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "cardinals",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SANDS",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Person",
#     "source": null,
#     "values": [
#       {
#         "value": "Lord John",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "RICHARD PLANTAGENET",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Edmund Mortimer",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "PRINCE EDWARD",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lieutenant BARDOLPH",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Owen Glendower",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "SIR WALTER BLUNT",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Julius Caesar",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Hastings",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "GEORGE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Edward Plantagenet",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "MARGARET JOURDAIN",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Salisbury",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "JOHN",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lady Constance",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "LORD ROSS",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Henry VIII",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Edward",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Ned Poins",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Duke Humphrey",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "lord chamberlain",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir John Falstaff",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "John Falstaff",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "KING EDWARD IV",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Henry VI",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sirrah",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Lewis",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt King Henry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "KING HENRY VI",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Cardinal",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lo",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King John",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Francis",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Robert Faulconbridge",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "QUEEN MARGARET",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Master Poins",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Hotspur",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "JACK FALSTAFF",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Henry Guildford",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Thomas Lovell",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "O Lewis",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Orleans",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "PETER",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "KING HENRY IV",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Edward King",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Gilbert Peck",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "sir Richard",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Richard II",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "chamberlain",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Warwick",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Richard Coeur-de-lion",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Henry King",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Cardinal Campeius",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "PRINCE HENRY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "ANNE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Clothair",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "HENRY BOLINGBROKE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir John Hume",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Dame Eleanor",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Henry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Nicholas Hopkins",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Aumerle",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt CHATILLON",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Noble earl",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt CLARENCE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "faint Henry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "KING PHILIP",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry Prince",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "John a Gaunt",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Robert",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Robin Ostler",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir John Sack",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Reignier",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "King Richard",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Angiers",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Henry IV",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "QUEEN KATHARINE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Gloucester",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sirrah Jack",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Richard Earl",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Arthur",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Thomas",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry Hereford",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Falstaff",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry Duke",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Humphrey Duke",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lady Blanch",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Clifford",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry Percy",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Corporal NYM",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt BARDOLPH",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord marshal",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Edward",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "QUEEN ELINOR",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry King",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "KING HENRY V",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Talbot",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord Bardolph",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt PRINCE HENRY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Prince Hal",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Henry Lord Scroop",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Richard",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir Walter",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "LORD WILLOUGHBY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "CARDINAL WOLSEY",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Arthur Plantagenet",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Sir John",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "QUEEN ELIZABETH",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Douglas",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Thomas Mowbray",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "uncle John",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Exeunt BUCKINGHAM",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Richard Gloucester",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "York",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "JOAN LA PUCELLE",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Lord marquess",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Prince Harry",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Poor Anne",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Harry Monmouth",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Prince Dauphin",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "Brakenbury",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Company",
#     "source": null,
#     "values": [
#       {
#         "value": "BLANCH",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "value": "CHATILLON",
#         "created": "2017-07-01T12:19:52.617Z",
#         "updated": "2017-07-01T12:19:52.617Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2017-07-01T12:19:52.617Z",
#     "updated": "2017-07-01T12:19:52.617Z",
#     "open_list": null,
#     "description": null
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**:
#
# City: Bardolph,
#     AUVERGNE,
#     Lancaster,
#     NORTHUMBERLAND,
#     Alarum. Enter YORK,
#     NORFOLK,
#     RUTLAND,
#     Anjou,
#     HASTINGS,
#     England,
#     BUCKINGHAM,
#     Dauphin,
#     Southampton,
#     WESTMORELAND,
#     Touraine,
#     Hereford,
#     Coventry,
#     Paris,
#     Gloucester,
#     Bretagne,
#     London,
#     SUFFOLK,
#     MONTAGUE,
#     Ravenspurgh,
#     Orleans,
#     WARWICK,
#     York,
#     SOMERSET,
#     Masham,
#     Shrewsbury,
#     Wiltshire,
#     Agincourt,
#     Worcester,
#     BEDFORD,
#     ELY,
#     Gadshill,
#     VERNON,
#     SALISBURY,
#     Angiers,
#     ABERGAVENNY,
#     EXETER,
#     DORSET,
#     Cambridge,
#     CANTERBURY,
#     Bagot,
#     Faulconbridge
#
# Facility:
#     the Tower,
#     Buckingham and Derby,
#     BISHOP OF ELY,
#     Lord John of Lancaster,
#     Ely House,
#     Lord of Lancaster
#
# Job Title:
#     ARCHBISHOP OF YORK,
#     Earl of Worcester,
#     BISHOPOF WINCHESTER,
#     BISHOP OF WINCHESTER,
#     Secretary

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**:
#
# Person: trigger=intent:#who
#
# Location: trigger=intent:#where
#
# Object: trigger=intent:#what

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who did Henry VI marry?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [
#     {
#       "intent": "who",
#       "confidence": 0.9000892639160156
#     }
#   ],
#   "entities": [
#     {
#       "entity": "Person",
#       "location": [
#         8,
#         16
#       ],
#       "value": "Henry VI",
#       "confidence": 1
#     }
#   ],
#   "input": {
#     "text": "Who did Henry VI marry?",
#     "context": {
#       "conversation_id": "028c4258-dc18-4a26-9ac8-7b0683b4eee0",
#       "system": {
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_turn_counter": 1,
#         "dialog_request_counter": 1
#       }
#     }
#   },
#   "output": {
#     "text": [
#       "Let me find out who for you."
#     ],
#     "nodes_visited": [
#       "Person"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "e3ae7c51-13cc-4656-8049-0495df14b88b",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "Person": [
#           0
#         ]
#       },
#       "branch_exited": true,
#       "branch_exited_reason": "completed"
#     }
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
# Then ask a sample question
question= "Where was Henry VI held captive?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [
#     {
#       "intent": "where",
#       "confidence": 1
#     }
#   ],
#   "entities": [
#     {
#       "entity": "Person",
#       "location": [
#         10,
#         18
#       ],
#       "value": "Henry VI",
#       "confidence": 1
#     }
#   ],
#   "input": {
#     "text": "Where was Henry VI held captive?",
#     "context": {
#       "conversation_id": "028c4258-dc18-4a26-9ac8-7b0683b4eee0",
#       "system": {
#         "dialog_stack": [
#           {
#             "dialog_node": "root"
#           }
#         ],
#         "dialog_turn_counter": 1,
#         "dialog_request_counter": 1
#       }
#     }
#   },
#   "output": {
#     "text": [
#       "Let me find where for you."
#     ],
#     "nodes_visited": [
#       "Location"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "ce820194-fa6a-4a2f-ab43-1c5b1c09b381",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "Location": [
#           0
#         ]
#       },
#       "branch_exited": true,
#       "branch_exited_reason": "completed"
#     }
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
import re

# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"].lower() for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"].lower() for entity in results["entities"]]
print("Entities:", query_entities)

query_input_original = results["input"]["text"]
query_input = query_input_original.lower()
query_input = re.sub(r'\W+',' ',query_input).split()
query_input = [ q for q in query_input if (len(q) > 2 and q not in query_intents and q not in query_entities)]
print("Dialog Input:", query_input)


# TODO: (optional) Find out what dialog node was triggered
query_output = results["output"]["text"]
print("Dialog Output:", query_output)
# Out:
# Intent(s): ['where']
# Entities: ['henry vi']
# Dialog Input: ['was', 'henry', 'held', 'captive']
# Dialog Output: ['Let me find where for you.']

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
queryoptions = "enriched_text.entities.text:{}".format(",".join("\"{}\"".format(e) for e in query_entities))
queryoptions += "," + "enriched_text.keywords.text:{}".format(",".join("\"{}\"".format(e) for e in query_input))
print(queryoptions)
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "passages": "true",
        "query": queryoptions,
        "return": "text"
    })
print(json.dumps(query_results, indent=2))
# Out:
# enriched_text.entities.text:"henry vi",enriched_text.keywords.text:"was","henry","held","captive"
# {
#   "matching_results": 0,
#   "passages": [],
#   "results": []
# }

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response
if query_results["matching_results"] > 0:
    print("The answer to your question: " + query_input_original)
    print("Is in this passsage: " + query_results["passages"][0]["passage_text"])
else:
    print("Unable to find a match to your question: ")
    print(query_input_original)
# Out:
# Unable to find a match to your question:
# Where was Henry VI held captive?

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
# The Watson services are powerful services, especially the Discovery Service.  I find though, that it will take a lot of Watson specific learning to fully understand the questions you want to answer and how those questions sentence structure best mirrors how Watson Discovery service extracts out the various enriched text types, and how best to use them.  For instance, I took the original input sentence and made keywords out of any words not already covered by the entities or intent returns from the Conversation service.  This was done in an attempt to narrow down the best matches.  I would think if I myself better understood sentence structure, and how the Discovery service utilizes that, I could have developed better query options to do the same thing.
#
# I was really impressed with the level of taxonomy and related concepts and links that Watson can find and make available.  There is a lot to learn here and how to use it.
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**: I used a Shakespeare History Plays as my dataset.  It was very different from typical english text of today,  Shakespearean prose and in script format.  While the discovery process seemed to find good entities and other extraction types, it wasn't very good at finding matches to my questions.
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
# I have included the 'shakepeare' folder in the zip file which contains an html set of files for each complete play in the 'history' set as found at this URL:
# http://shakespeare.mit.edu/works.html
#
# The submitted bookworm-shakespeare.ipynb and .html files contain the python code to process and query these files.  I did NOT re-answer the Q&A cells in that notebook, so they reflect my answers from this Star Wars oriented notebook.
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
